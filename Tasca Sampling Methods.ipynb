# %%
import pandas as pd
import sqlite3
import numpy as np

# %%
#importing all the required ML packages
from sklearn.linear_model import LogisticRegression #logistic regression
from sklearn import svm #support vector Machine
from sklearn.ensemble import RandomForestClassifier #Random Forest
from sklearn.neighbors import KNeighborsClassifier #KNN
from sklearn.naive_bayes import GaussianNB #Naive bayes
from sklearn.tree import DecisionTreeClassifier #Decision Tree
from sklearn.model_selection import train_test_split #training and testing data split
from sklearn import metrics #accuracy measure
from sklearn.metrics import confusion_matrix #for confusion matrix

# Generate and plot a synthetic imbalanced classification dataset
from collections import Counter
from sklearn.datasets import make_classification
from matplotlib import pyplot

# %% [markdown]
# ### Importación de tablas

# %%
conn = sqlite3.connect('database.sqlite')

# %%
team_query = '''select * from Team''' 
player_query = '''select * from Player'''
player_attributes_query = '''select * from Player_Attributes'''
match_query = '''select * from Match'''
league_query = '''select * from League'''

# %%
team = pd.read_sql_query(team_query,conn)
player = pd.read_sql_query(player_query,conn)
player_attributes = pd.read_sql_query(player_attributes_query,conn)
match = pd.read_sql_query(match_query,conn)
league = pd.read_sql_query(league_query,conn)

# %% [markdown]
# ### Exploración base de datos, selección de principales variables y primer preprocesamiento

# %%
league.head()
# Out:
#       id  country_id                    name
# 0      1           1  Belgium Jupiler League
# 1   1729        1729  England Premier League
# 2   4769        4769          France Ligue 1
# 3   7809        7809   Germany 1. Bundesliga
# 4  10257       10257           Italy Serie A

# %%
match.head()
# Out:
#    id  country_id  league_id     season  stage                 date  \
# 0   1           1          1  2008/2009      1  2008-08-17 00:00:00
# 1   2           1          1  2008/2009      1  2008-08-16 00:00:00
# 2   3           1          1  2008/2009      1  2008-08-16 00:00:00
# 3   4           1          1  2008/2009      1  2008-08-17 00:00:00
# 4   5           1          1  2008/2009      1  2008-08-16 00:00:00
#
#    match_api_id  home_team_api_id  away_team_api_id  home_team_goal  ...  \
# 0        492473              9987              9993               1  ...
# 1        492474             10000              9994               0  ...
# 2        492475              9984              8635               0  ...
# 3        492476              9991              9998               5  ...
# 4        492477              7947              9985               1  ...
#
#     SJA   VCH   VCD   VCA   GBH   GBD   GBA   BSH   BSD   BSA
# 0  4.00  1.65  3.40  4.50  1.78  3.25  4.00  1.73  3.40  4.20
# 1  3.80  2.00  3.25  3.25  1.85  3.25  3.75  1.91  3.25  3.60
# 2  2.50  2.35  3.25  2.65  2.50  3.20  2.50  2.30  3.20  2.75
# 3  7.50  1.45  3.75  6.50  1.50  3.75  5.50  1.44  3.75  6.50
# 4  1.73  4.50  3.40  1.65  4.50  3.50  1.65  4.75  3.30  1.67
#
# [5 rows x 115 columns]

# %%
team.head(10)
# Out:
#    id  team_api_id  team_fifa_api_id     team_long_name team_short_name
# 0   1         9987             673.0           KRC Genk             GEN
# 1   2         9993             675.0       Beerschot AC             BAC
# 2   3        10000           15005.0   SV Zulte-Waregem             ZUL
# 3   4         9994            2007.0   Sporting Lokeren             LOK
# 4   5         9984            1750.0  KSV Cercle Brugge             CEB
# 5   6         8635             229.0     RSC Anderlecht             AND
# 6   7         9991             674.0           KAA Gent             GEN
# 7   8         9998            1747.0          RAEC Mons             MON
# 8   9         7947               NaN      FCV Dender EH             DEN
# 9  10         9985             232.0  Standard de Liège             STL

# %%
# Populating Team Names

match['home_team'] = match['home_team_api_id'].map(team.set_index('team_api_id')['team_long_name'])
match['away_team'] = match['away_team_api_id'].map(team.set_index('team_api_id')['team_long_name'])
match['league_country'] = match['country_id'].map(league.set_index('country_id')['name'])

# %%
status_values = ['win', 'lose', 'draw']

general_values = ['home win', 'away win', 'draw']
general_encoded_values = [0, 1, 2]

home_conditions = [(match['home_team_goal']>match['away_team_goal']), (match['home_team_goal']<match['away_team_goal']), (match['home_team_goal']==match['away_team_goal'])]

away_conditions = [(match['home_team_goal']<match['away_team_goal']), (match['home_team_goal']>match['away_team_goal']), (match['home_team_goal']==match['away_team_goal'])]

# %%
match['general_result'] = np.select(home_conditions, general_values)

# %%
match['general_encoded_result'] = np.select(home_conditions, general_encoded_values)

# %%
match['home_result'] = np.select(home_conditions, status_values)

# %%
match['away_result'] = np.select(away_conditions, status_values)

# %%
# Selecting main columns:

match = match[['date', 'id', 'league_id', 'country_id', 'league_country', 'season', 'match_api_id', 'home_team_api_id', 'home_team', 'away_team_api_id', 'away_team', 'home_team_goal', 'away_team_goal', 'home_result', 'general_result', 'general_encoded_result', 'away_result', 'B365H', 'B365A', 'B365D']]

# %%
match.head(10)
# Out:
#                   date  id  league_id  country_id          league_country  \
# 0  2008-08-17 00:00:00   1          1           1  Belgium Jupiler League
# 1  2008-08-16 00:00:00   2          1           1  Belgium Jupiler League
# 2  2008-08-16 00:00:00   3          1           1  Belgium Jupiler League
# 3  2008-08-17 00:00:00   4          1           1  Belgium Jupiler League
# 4  2008-08-16 00:00:00   5          1           1  Belgium Jupiler League
# 5  2008-09-24 00:00:00   6          1           1  Belgium Jupiler League
# 6  2008-08-16 00:00:00   7          1           1  Belgium Jupiler League
# 7  2008-08-16 00:00:00   8          1           1  Belgium Jupiler League
# 8  2008-08-16 00:00:00   9          1           1  Belgium Jupiler League
# 9  2008-11-01 00:00:00  10          1           1  Belgium Jupiler League
#
#       season  match_api_id  home_team_api_id          home_team  \
# 0  2008/2009        492473              9987           KRC Genk
# 1  2008/2009        492474             10000   SV Zulte-Waregem
# 2  2008/2009        492475              9984  KSV Cercle Brugge
# 3  2008/2009        492476              9991           KAA Gent
# 4  2008/2009        492477              7947      FCV Dender EH
# 5  2008/2009        492478              8203        KV Mechelen
# 6  2008/2009        492479              9999      KSV Roeselare
# 7  2008/2009        492480              4049             Tubize
# 8  2008/2009        492481             10001       KVC Westerlo
# 9  2008/2009        492564              8342     Club Brugge KV
#
#    away_team_api_id             away_team  home_team_goal  away_team_goal  \
# 0              9993          Beerschot AC               1               1
# 1              9994      Sporting Lokeren               0               0
# 2              8635        RSC Anderlecht               0               3
# 3              9998             RAEC Mons               5               0
# 4              9985     Standard de Liège               1               3
# 5              8342        Club Brugge KV               1               1
# 6              8571           KV Kortrijk               2               2
# 7              9996  Royal Excel Mouscron               1               2
# 8              9986    Sporting Charleroi               1               0
# 9              8571           KV Kortrijk               4               1
#
#   home_result general_result  general_encoded_result away_result  B365H  \
# 0        draw           draw                       2        draw   1.73
# 1        draw           draw                       2        draw   1.95
# 2        lose       away win                       1         win   2.38
# 3         win       home win                       0        lose   1.44
# 4        lose       away win                       1         win   5.00
# 5        draw           draw                       2        draw   4.75
# 6        draw           draw                       2        draw   2.10
# 7        lose       away win                       1         win   3.20
# 8         win       home win                       0        lose   2.25
# 9         win       home win                       0        lose   1.30
#
#    B365A  B365D
# 0   5.00   3.40
# 1   3.60   3.20
# 2   2.75   3.30
# 3   7.50   3.75
# 4   1.65   3.50
# 5   1.67   3.40
# 6   3.30   3.20
# 7   2.20   3.40
# 8   2.88   3.25
# 9   9.50   5.25

# %%
match.league_country.value_counts()
# Out:
# Spain LIGA BBVA             3040
# France Ligue 1              3040
# England Premier League      3040
# Italy Serie A               3017
# Germany 1. Bundesliga       2448
# Netherlands Eredivisie      2448
# Portugal Liga ZON Sagres    2052
# Poland Ekstraklasa          1920
# Scotland Premier League     1824
# Belgium Jupiler League      1728
# Switzerland Super League    1422
# Name: league_country, dtype: int64

# %%
# Amount of NA's

match.isna().sum()
# Out:
# date                         0
# id                           0
# league_id                    0
# country_id                   0
# league_country               0
# season                       0
# match_api_id                 0
# home_team_api_id             0
# home_team                    0
# away_team_api_id             0
# away_team                    0
# home_team_goal               0
# away_team_goal               0
# home_result                  0
# general_result               0
# general_encoded_result       0
# away_result                  0
# B365H                     3387
# B365A                     3387
# B365D                     3387
# dtype: int64

# %%
# Countries with missing values on Betting columns information --> Remove Poland and Switzerland and fill other countrie's NA's with mean

match[match['B365H'].isna()].league_country.value_counts()
# Out:
# Poland Ekstraklasa          1920
# Switzerland Super League    1422
# Belgium Jupiler League        22
# Portugal Liga ZON Sagres       8
# Italy Serie A                  6
# France Ligue 1                 4
# Netherlands Eredivisie         3
# Germany 1. Bundesliga          1
# Spain LIGA BBVA                1
# Name: league_country, dtype: int64

# %%
# Removing Poland and Switzerland

match_final = match.loc[(match['league_country'] != 'Poland Ekstraklasa') & (match['league_country'] != 'Switzerland Super League')]

# %%
match_final.groupby('league_country').mean()
# Out:
#                                id  league_id  country_id  match_api_id  \
# league_country
# Belgium Jupiler League      864.5        1.0         1.0  1.123332e+06
# England Premier League     3248.5     1729.0      1729.0  1.178767e+06
# France Ligue 1             6288.5     4769.0      4769.0  1.171642e+06
# Germany 1. Bundesliga      9032.5     7809.0      7809.0  1.189377e+06
# Italy Serie A             11765.0    10257.0     10257.0  1.236752e+06
# Netherlands Eredivisie    14497.5    13274.0     13274.0  1.180382e+06
# Portugal Liga ZON Sagres  18667.5    17642.0     17642.0  1.246115e+06
# Scotland Premier League   20605.5    19694.0     19694.0  1.204328e+06
# Spain LIGA BBVA           23037.5    21518.0     21518.0  1.214688e+06
#
#                           home_team_api_id  away_team_api_id  home_team_goal  \
# league_country
# Belgium Jupiler League        13810.710648      13810.710648        1.609375
# England Premier League         9142.275000       9142.275000        1.550987
# France Ligue 1                 9808.300000       9808.300000        1.402961
# Germany 1. Bundesliga          9180.250000       9180.250000        1.626634
# Italy Serie A                 10345.651641      10346.633079        1.500829
# Netherlands Eredivisie         9181.388889       9181.388889        1.779820
# Portugal Liga ZON Sagres      13952.262671      13952.262671        1.408382
# Scotland Premier League        9130.754386       9130.599781        1.429276
# Spain LIGA BBVA                9032.287500       9032.287500        1.631250
#
#                           away_team_goal  general_encoded_result     B365H  \
# league_country
# Belgium Jupiler League          1.192130                0.777199  2.412849
# England Premier League          1.159539                0.800329  2.701964
# France Ligue 1                  1.040132                0.835526  2.409911
# Germany 1. Bundesliga           1.274918                0.791667  2.596530
# Italy Serie A                   1.116009                0.797481  2.506616
# Netherlands Eredivisie          1.301062                0.758987  2.590569
# Portugal Liga ZON Sagres        1.126218                0.817251  2.938415
# Scotland Premier League         1.204496                0.828399  2.800493
# Spain LIGA BBVA                 1.135855                0.743092  2.762152
#
#                              B365A     B365D
# league_country
# Belgium Jupiler League    4.310481  3.751553
# England Premier League    4.910437  3.952720
# France Ligue 1            4.389489  3.437790
# Germany 1. Bundesliga     4.375509  3.913788
# Italy Serie A             4.555254  3.599661
# Netherlands Eredivisie    4.916953  4.124834
# Portugal Liga ZON Sagres  4.784946  3.804976
# Scotland Premier League   4.174359  3.821765
# Spain LIGA BBVA           5.226018  4.160408

# %%
### Filling NA's with mean -->> See how to automate with a function

match_final.loc[(match_final.league_country == 'Belgium Jupiler League') & (match_final.B365D.isnull()), 'B365D'] = 3.751
match_final.loc[(match_final.league_country == 'Portugal Liga ZON Sagres') & (match_final.B365D.isnull()), 'B365D'] = 3.804
match_final.loc[(match_final.league_country == 'Italy Serie A') & (match_final.B365D.isnull()), 'B365D'] = 3.599
match_final.loc[(match_final.league_country == 'France Ligue 1') & (match_final.B365D.isnull()), 'B365D'] = 3.437
match_final.loc[(match_final.league_country == 'Netherlands Eredivisie') & (match_final.B365D.isnull()), 'B365D'] = 4.124
match_final.loc[(match_final.league_country == 'Spain LIGA BBVA') & (match_final.B365D.isnull()), 'B365D'] = 4.16
match_final.loc[(match_final.league_country == 'Germany 1. Bundesliga') & (match_final.B365D.isnull()), 'B365D'] = 3.913

match_final.loc[(match_final.league_country == 'Belgium Jupiler League') & (match_final.B365A.isnull()), 'B365A'] = 4.310
match_final.loc[(match_final.league_country == 'Portugal Liga ZON Sagres') & (match_final.B365A.isnull()), 'B365A'] = 4.784
match_final.loc[(match_final.league_country == 'Italy Serie A') & (match_final.B365A.isnull()), 'B365A'] = 4.555
match_final.loc[(match_final.league_country == 'France Ligue 1') & (match_final.B365A.isnull()), 'B365A'] = 4.389
match_final.loc[(match_final.league_country == 'Netherlands Eredivisie') & (match_final.B365A.isnull()), 'B365A'] = 4.916
match_final.loc[(match_final.league_country == 'Spain LIGA BBVA') & (match_final.B365A.isnull()), 'B365A'] = 5.22
match_final.loc[(match_final.league_country == 'Germany 1. Bundesliga') & (match_final.B365A.isnull()), 'B365A'] = 4.375

match_final.loc[(match_final.league_country == 'Belgium Jupiler League') & (match_final.B365H.isnull()), 'B365H'] = 2.412
match_final.loc[(match_final.league_country == 'Portugal Liga ZON Sagres') & (match_final.B365H.isnull()), 'B365H'] = 2.938
match_final.loc[(match_final.league_country == 'Italy Serie A') & (match_final.B365H.isnull()), 'B365H'] = 2.506
match_final.loc[(match_final.league_country == 'France Ligue 1') & (match_final.B365H.isnull()), 'B365H'] = 2.409
match_final.loc[(match_final.league_country == 'Netherlands Eredivisie') & (match_final.B365H.isnull()), 'B365H'] = 2.590
match_final.loc[(match_final.league_country == 'Spain LIGA BBVA') & (match_final.B365H.isnull()), 'B365H'] = 2.762
match_final.loc[(match_final.league_country == 'Germany 1. Bundesliga') & (match_final.B365H.isnull()), 'B365H'] = 2.596
# Out:
# C:\Users\tomi_\Anaconda3\lib\site-packages\pandas\core\indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
match_final['3+_goals_diff'] = np.where(((match_final['home_team_goal']-match_final['away_team_goal']>2) | (match_final['away_team_goal']-match_final['home_team_goal']>2)), 1, 0)
# Out:
# C:\Users\tomi_\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
match_final.head()
# Out:
#                   date  id  league_id  country_id          league_country  \
# 0  2008-08-17 00:00:00   1          1           1  Belgium Jupiler League
# 1  2008-08-16 00:00:00   2          1           1  Belgium Jupiler League
# 2  2008-08-16 00:00:00   3          1           1  Belgium Jupiler League
# 3  2008-08-17 00:00:00   4          1           1  Belgium Jupiler League
# 4  2008-08-16 00:00:00   5          1           1  Belgium Jupiler League
#
#       season  match_api_id  home_team_api_id          home_team  \
# 0  2008/2009        492473              9987           KRC Genk
# 1  2008/2009        492474             10000   SV Zulte-Waregem
# 2  2008/2009        492475              9984  KSV Cercle Brugge
# 3  2008/2009        492476              9991           KAA Gent
# 4  2008/2009        492477              7947      FCV Dender EH
#
#    away_team_api_id  ... home_team_goal  away_team_goal  home_result  \
# 0              9993  ...              1               1         draw
# 1              9994  ...              0               0         draw
# 2              8635  ...              0               3         lose
# 3              9998  ...              5               0          win
# 4              9985  ...              1               3         lose
#
#   general_result general_encoded_result  away_result B365H  B365A  B365D  \
# 0           draw                      2         draw  1.73   5.00   3.40
# 1           draw                      2         draw  1.95   3.60   3.20
# 2       away win                      1          win  2.38   2.75   3.30
# 3       home win                      0         lose  1.44   7.50   3.75
# 4       away win                      1          win  5.00   1.65   3.50
#
#    3+_goals_diff
# 0              0
# 1              0
# 2              1
# 3              1
# 4              0
#
# [5 rows x 21 columns]

# %%
### Defining X and y

X = match_final.drop(['general_result', 'general_encoded_result'], axis=1)
y = match_final['general_result']

# %%
match_final.tail()
# Out:
#                       date     id  league_id  country_id   league_country  \
# 24552  2015-10-25 00:00:00  24553      21518       21518  Spain LIGA BBVA
# 24553  2015-10-24 00:00:00  24554      21518       21518  Spain LIGA BBVA
# 24554  2015-10-26 00:00:00  24555      21518       21518  Spain LIGA BBVA
# 24555  2015-10-24 00:00:00  24556      21518       21518  Spain LIGA BBVA
# 24556  2015-10-23 00:00:00  24557      21518       21518  Spain LIGA BBVA
#
#           season  match_api_id  home_team_api_id                home_team  \
# 24552  2015/2016       2030167              9906          Atlético Madrid
# 24553  2015/2016       2030168              9864                Málaga CF
# 24554  2015/2016       2030169              8315  Athletic Club de Bilbao
# 24555  2015/2016       2030170              7878               Granada CF
# 24556  2015/2016       2030171              8370           Rayo Vallecano
#
#        away_team_api_id  ... home_team_goal  away_team_goal  home_result  \
# 24552             10267  ...              2               1          win
# 24553              9783  ...              2               0          win
# 24554              9869  ...              3               0          win
# 24555              8603  ...              1               1         draw
# 24556              8558  ...              3               0          win
#
#       general_result general_encoded_result  away_result B365H  B365A  B365D  \
# 24552       home win                      0         lose  1.57   6.50   3.80
# 24553       home win                      0         lose  2.25   3.40   3.25
# 24554       home win                      0         lose  1.53   7.00   4.00
# 24555           draw                      2         draw  2.30   3.25   3.25
# 24556       home win                      0         lose  2.20   3.20   3.40
#
#        3+_goals_diff
# 24552              0
# 24553              0
# 24554              1
# 24555              0
# 24556              1
#
# [5 rows x 21 columns]

# %% [markdown]
# # EJERCICIO 1

# %% [markdown]
# ## Simple Random Sample

# %% [markdown]
# Using a third of the population as sample

# %%
sample_size = round((len(match_final)/3), 0)
#sample_size = int(match_final)
sample_size
# Out:
# 7546.0

# %%
random_sample = match_final.sample(n=int(sample_size), random_state=42)
random_sample
# Out:
#                       date     id  league_id  country_id  \
# 4579   2016-04-20 00:00:00   4580       1729        1729
# 12893  2015-08-23 00:00:00  12894      10257       10257
# 134    2009-02-14 00:00:00    135          1           1
# 14887  2013-12-22 00:00:00  14888      13274       13274
# 7159   2014-08-15 00:00:00   7160       4769        4769
# ...                    ...    ...        ...         ...
# 2807   2011-05-22 00:00:00   2808       1729        1729
# 18740  2013-04-05 00:00:00  18741      17642       17642
# 19175  2015-01-31 00:00:00  19176      17642       17642
# 19219  2015-02-27 00:00:00  19220      17642       17642
# 19518  2016-02-12 00:00:00  19519      17642       17642
#
#                  league_country     season  match_api_id  home_team_api_id  \
# 4579     England Premier League  2015/2016       1988971              8650
# 12893             Italy Serie A  2015/2016       2060255              8534
# 134      Belgium Jupiler League  2008/2009        493006              9996
# 14887    Netherlands Eredivisie  2013/2014       1473179              8674
# 7159             France Ligue 1  2014/2015       1709708              7819
# ...                         ...        ...           ...               ...
# 2807     England Premier League  2010/2011        840234             10194
# 18740  Portugal Liga ZON Sagres  2012/2013       1256537             10212
# 19175  Portugal Liga ZON Sagres  2014/2015       1750641              6547
# 19219  Portugal Liga ZON Sagres  2014/2015       1750676              7844
# 19518  Portugal Liga ZON Sagres  2015/2016       2016003              9772
#
#                   home_team  away_team_api_id  ... home_team_goal  \
# 4579              Liverpool              8668  ...              4
# 12893                Empoli              8533  ...              1
# 134    Royal Excel Mouscron             10001  ...              0
# 14887          FC Groningen              8464  ...              5
# 7159                SM Caen              8639  ...              0
# ...                     ...               ...  ...            ...
# 2807             Stoke City              8528  ...              0
# 18740           CS Marítimo              6403  ...              1
# 19175           FC Penafiel              7844  ...              1
# 19219     Vitória Guimarães             10212  ...              1
# 19518            SL Benfica              9773  ...              1
#
#        away_team_goal  home_result general_result general_encoded_result  \
# 4579                0          win       home win                      0
# 12893               3         lose       away win                      1
# 134                 0         draw           draw                      2
# 14887               2          win       home win                      0
# 7159                1         lose       away win                      1
# ...               ...          ...            ...                    ...
# 2807                1         lose       away win                      1
# 18740               1         draw           draw                      2
# 19175               1         draw           draw                      2
# 19219               0          win       home win                      0
# 19518               2         lose       away win                      1
#
#        away_result B365H  B365A  B365D  3+_goals_diff
# 4579          lose  1.73   5.00   4.00              1
# 12893          win  2.15   3.60   3.25              0
# 134           draw  2.40   2.70   3.30              0
# 14887         lose  1.67   4.75   4.00              1
# 7159           win  3.60   2.15   3.10              0
# ...            ...   ...    ...    ...            ...
# 2807           win  2.75   2.40   3.60              0
# 18740         draw  2.38   3.20   3.00              0
# 19175         draw  4.50   1.73   3.75              0
# 19219         lose  1.75   4.33   3.75              0
# 19518          win  2.15   3.50   3.10              0
#
# [7546 rows x 21 columns]

# %%
# Sample size verification

len(random_sample)
# Out:
# 7546

# %% [markdown]
# ### Simple random sampling using train test split

# %%
X_train_random, X_test_random, y_train_random, y_test_random = train_test_split(X, y, test_size = 1/3, random_state = 42)

# %%
y_train_random.describe()
# Out:
# count        15091
# unique           3
# top       home win
# freq          6921
# Name: general_result, dtype: object

# %%
y_test_random.describe()
# Out:
# count         7546
# unique           3
# top       home win
# freq          3476
# Name: general_result, dtype: object

# %% [markdown]
# ## Systematic Sample

# %%
# Define systematic sampling function
def systematic_sampling(match_final, step):
  
    indexes = np.arange(0, len(match_final), step=step)
    systematic_sample = match_final.iloc[indexes]
    return systematic_sample
  
  
# Obtain a systematic sample and save it in a new variable
systematic_sample = systematic_sampling(match_final, 3)
  
# View sampled data frame
print('Original sample has been divided into interval of 3 resulting in a new sample of', len(systematic_sample), 'records.')
# Out:
# Original sample has been divided into interval of 3 resulting in a new sample of 7546 records.

# %% [markdown]
# # EJERCICIO 2

# %% [markdown]
# ## Stratified Sample

# %%
#define total sample size desired
N = 7546

#perform stratified random sampling
stratified_sample = match_final.groupby('league_country', group_keys=False).apply(lambda x: x.sample(int(np.rint(N*len(x)/len(match_final))))).sample(frac=1).reset_index(drop=True)

# %%
stratified_sample.head()
# Out:
#                   date     id  league_id  country_id  \
# 0  2008-11-30 00:00:00  10308      10257       10257
# 1  2009-02-01 00:00:00  10400      10257       10257
# 2  2012-04-11 00:00:00  11633      10257       10257
# 3  2014-03-07 00:00:00  18959      17642       17642
# 4  2011-09-10 00:00:00   8992       7809        7809
#
#              league_country     season  match_api_id  home_team_api_id  \
# 0             Italy Serie A  2008/2009        539688             10233
# 1             Italy Serie A  2008/2009        539772             10233
# 2             Italy Serie A  2011/2012       1083224              8636
# 3  Portugal Liga ZON Sagres  2013/2014       1498185              7841
# 4     Germany 1. Bundesliga  2011/2012       1029843             10269
#
#        home_team  away_team_api_id  ... home_team_goal  away_team_goal  \
# 0          Genoa              9857  ...              1               1
# 1          Genoa              8540  ...              1               0
# 2          Inter              8551  ...              2               1
# 3     Rio Ave FC             10215  ...              0               0
# 4  VfB Stuttgart              9904  ...              3               0
#
#    home_result general_result general_encoded_result  away_result B365H  \
# 0         draw           draw                      2         draw  1.62
# 1          win       home win                      0         lose  1.90
# 2          win       home win                      0         lose  1.62
# 3         draw           draw                      2         draw  1.95
# 4          win       home win                      0         lose  1.85
#
#    B365A  B365D  3+_goals_diff
# 0   6.50    3.4              0
# 1   4.75    3.2              0
# 2   5.50    3.8              0
# 3   4.20    3.2              0
# 4   4.00    3.6              1
#
# [5 rows x 21 columns]

# %% [markdown]
# STRATIFIED SAMPLE VERIFICATION

# %%
stratified_sample.league_country.value_counts()/len(stratified_sample)
# Out:
# Spain LIGA BBVA             0.134261
# England Premier League      0.134261
# France Ligue 1              0.134261
# Italy Serie A               0.133333
# Germany 1. Bundesliga       0.108151
# Netherlands Eredivisie      0.108151
# Portugal Liga ZON Sagres    0.090656
# Scotland Premier League     0.080583
# Belgium Jupiler League      0.076342
# Name: league_country, dtype: float64

# %%
match_final.league_country.value_counts()/len(match_final)
# Out:
# Spain LIGA BBVA             0.134293
# France Ligue 1              0.134293
# England Premier League      0.134293
# Italy Serie A               0.133277
# Germany 1. Bundesliga       0.108142
# Netherlands Eredivisie      0.108142
# Portugal Liga ZON Sagres    0.090648
# Scotland Premier League     0.080576
# Belgium Jupiler League      0.076335
# Name: league_country, dtype: float64

# %% [markdown]
# ### Stratified sample using train_test_split

# %%
X_train_stratified, X_test_stratified, y_train_stratified, y_test_stratified = train_test_split(X, y, test_size=1/3, stratify=y)

# %%
y_train_stratified.value_counts()/len(y_train_stratified)
# Out:
# home win    0.459280
# away win    0.287787
# draw        0.252932
# Name: general_result, dtype: float64

# %%
y_test_stratified.value_counts()/len(y_test_stratified)
# Out:
# home win    0.459316
# away win    0.287835
# draw        0.252849
# Name: general_result, dtype: float64

# %% [markdown]
# ### SMOTE Sampling (synthetic minority oversample techniche)

# %%
#pip install imbalanced-learn --user

# %%
from imblearn.over_sampling import SMOTE

# %%
# Identification of imbalanced proportion in sample: 

match_final['3+_goals_diff'].value_counts()/len(match_final)
# Out:
# 0    0.843398
# 1    0.156602
# Name: 3+_goals_diff, dtype: float64

# %%
# Selection of numerical values to implement SMOTE analysis

X_smote = match_final[['id', 'league_id', 'home_team_api_id', 'home_team_api_id', 'home_team_goal', 'away_team_goal', 'B365H', 'B365A', 'B365D', '3+_goals_diff']].values
y_smote = match_final['general_encoded_result']

# %%
sm = SMOTE(random_state=42)

X_sm, y_sm = sm.fit_resample(X_smote, y_smote)

print(f'''Shape of X before SMOTE: {X.shape}
Shape of X after SMOTE: {X_sm.shape}''')

print('\nBalance of positive and negative classes (%):')
y_sm.value_counts(normalize=True) * 100
# Out:
# Shape of X before SMOTE: (22637, 19)
# Shape of X after SMOTE: (31191, 10)
#
# Balance of positive and negative classes (%):
# 2    33.333333
# 1    33.333333
# 0    33.333333
# Name: general_encoded_result, dtype: float64

# %% [markdown]
# # EJERCICIO 3

# %% [markdown]
# ## Reservoir Sampling

# %%
import random

# %%
stream = match_final.to_numpy()

# %%
N=7546
reservoir = []

# Function definition

for i, element in enumerate(stream):
    if i+1<=N:
        reservoir.append(element)
    else:
        probability = N/(i+N)
        if random.random() < probability:
            reservoir[random.choice(range(0,N))] = element
            

print(reservoir)
# Out:
# [array(['2008-08-17 00:00:00', 1, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492473, 9987, 'KRC Genk', 9993, 'Beerschot AC', 1, 1,
#        'draw', 'draw', 2, 'draw', 1.73, 5.0, 3.4, 0], dtype=object), array(['2013-09-21 00:00:00', 9613, 7809, 7809, 'Germany 1. Bundesliga',
#        '2013/2014', 1479039, 8721, 'VfL Wolfsburg', 8226,
#        'TSG 1899 Hoffenheim', 2, 1, 'win', 'home win', 0, 'lose', 1.73,
#        4.2, 4.0, 0], dtype=object), array(['2008-08-16 00:00:00', 3, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492475, 9984, 'KSV Cercle Brugge', 8635,
#        'RSC Anderlecht', 0, 3, 'lose', 'away win', 1, 'win', 2.38, 2.75,
#        3.3, 1], dtype=object), array(['2016-03-04 00:00:00', 19549, 17642, 17642,
#        'Portugal Liga ZON Sagres', '2015/2016', 2016033, 6403,
#        'FC Paços de Ferreira', 10212, 'CS Marítimo', 2, 2, 'draw', 'draw',
#        2, 'draw', 2.45, 2.9, 3.25, 0], dtype=object), array(['2008-08-16 00:00:00', 5, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492477, 7947, 'FCV Dender EH', 9985,
#        'Standard de Liège', 1, 3, 'lose', 'away win', 1, 'win', 5.0, 1.65,
#        3.5, 0], dtype=object), array(['2011-09-20 00:00:00', 11702, 10257, 10257, 'Italy Serie A',
#        '2011/2012', 1082984, 6269, 'Novara', 8636, 'Inter', 3, 1, 'win',
#        'home win', 0, 'lose', 6.0, 1.62, 3.6, 0], dtype=object), array(['2008-08-16 00:00:00', 7, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492479, 9999, 'KSV Roeselare', 8571, 'KV Kortrijk', 2,
#        2, 'draw', 'draw', 2, 'draw', 2.1, 3.3, 3.2, 0], dtype=object), array(['2008-08-16 00:00:00', 8, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492480, 4049, 'Tubize', 9996, 'Royal Excel Mouscron',
#        1, 2, 'lose', 'away win', 1, 'win', 3.2, 2.2, 3.4, 0], dtype=object), array(['2009-04-25 00:00:00', 8000, 7809, 7809, 'Germany 1. Bundesliga',
#        '2008/2009', 499571, 9789, 'Borussia Dortmund', 9790,
#        'Hamburger SV', 2, 0, 'win', 'home win', 0, 'lose', 2.2, 3.1, 3.3,
#        0], dtype=object), array(['2016-01-16 00:00:00', 24304, 21518, 21518, 'Spain LIGA BBVA',
#        '2015/2016', 2030354, 10205, 'Villarreal CF', 8603,
#        'Real Betis Balompié', 0, 0, 'draw', 'draw', 2, 'draw', 1.45, 8.0,
#        4.33, 0], dtype=object), array(['2008-10-31 00:00:00', 11, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492565, 9985, 'Standard de Liège', 9986,
#        'Sporting Charleroi', 1, 2, 'lose', 'away win', 1, 'win', 1.3, 9.5,
#        5.25, 0], dtype=object), array(['2008-11-09 00:00:00', 21533, 21518, 21518, 'Spain LIGA BBVA',
#        '2008/2009', 530238, 10205, 'Villarreal CF', 9865, 'UD Almería', 2,
#        1, 'win', 'home win', 0, 'lose', 1.53, 7.0, 3.75, 0], dtype=object), array(['2008-11-01 00:00:00', 13, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492567, 9994, 'Sporting Lokeren', 9998, 'RAEC Mons',
#        0, 0, 'draw', 'draw', 2, 'draw', 1.91, 4.0, 3.4, 0], dtype=object), array(['2015-01-05 00:00:00', 21136, 19694, 19694,
#        'Scotland Premier League', '2014/2015', 1726135, 8597,
#        'Kilmarnock', 9925, 'Celtic', 0, 2, 'lose', 'away win', 1, 'win',
#        13.0, 1.22, 6.0, 0], dtype=object), array(['2008-11-01 00:00:00', 15, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492569, 8203, 'KV Mechelen', 9999, 'KSV Roeselare', 1,
#        2, 'lose', 'away win', 1, 'win', 1.7, 4.5, 3.3, 0], dtype=object), array(['2008-11-01 00:00:00', 16, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492570, 9996, 'Royal Excel Mouscron', 9984,
#        'KSV Cercle Brugge', 0, 1, 'lose', 'away win', 1, 'win', 2.35, 3.0,
#        3.3, 0], dtype=object), array(['2008-11-01 00:00:00', 17, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492571, 4049, 'Tubize', 9987, 'KRC Genk', 1, 3,
#        'lose', 'away win', 1, 'win', 6.0, 1.57, 3.75, 0], dtype=object), array(['2015-02-03 00:00:00', 9741, 7809, 7809, 'Germany 1. Bundesliga',
#        '2014/2015', 1732889, 9810, 'Eintracht Frankfurt', 8721,
#        'VfL Wolfsburg', 1, 1, 'draw', 'draw', 2, 'draw', 3.8, 1.85, 4.0,
#        0], dtype=object), array(['2012-11-04 00:00:00', 18831, 17642, 17642,
#        'Portugal Liga ZON Sagres', '2012/2013', 1256565, 10215,
#        'Académica de Coimbra', 7842, 'Estoril Praia', 0, 2, 'lose',
#        'away win', 1, 'win', 2.05, 3.75, 3.25, 0], dtype=object), array(['2008-11-08 00:00:00', 20, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492574, 9998, 'RAEC Mons', 9996,
#        'Royal Excel Mouscron', 0, 0, 'draw', 'draw', 2, 'draw', 2.4, 2.9,
#        3.3, 0], dtype=object), array(['2008-11-09 00:00:00', 21, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492575, 9986, 'Sporting Charleroi', 8342,
#        'Club Brugge KV', 2, 2, 'draw', 'draw', 2, 'draw', 3.2, 2.25, 3.3,
#        0], dtype=object), array(['2008-11-07 00:00:00', 22, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492576, 9984, 'KSV Cercle Brugge', 10000,
#        'SV Zulte-Waregem', 2, 0, 'win', 'home win', 0, 'lose', 1.75, 4.33,
#        3.75, 0], dtype=object), array(['2011-02-27 00:00:00', 18231, 17642, 17642,
#        'Portugal Liga ZON Sagres', '2010/2011', 859811, 10214,
#        'CD Nacional', 9768, 'Sporting CP', 1, 0, 'win', 'home win', 0,
#        'lose', 3.5, 2.1, 3.25, 0], dtype=object), array(['2016-04-24 00:00:00', 7717, 4769, 4769, 'France Ligue 1',
#        '2015/2016', 1990078, 9851, 'Stade Rennais FC', 9829, 'AS Monaco',
#        1, 1, 'draw', 'draw', 2, 'draw', 2.7, 2.8, 3.1, 0], dtype=object), array(['2011-03-05 00:00:00', 8581, 7809, 7809, 'Germany 1. Bundesliga',
#        '2010/2011', 857256, 9904, 'Hannover 96', 9823, 'FC Bayern Munich',
#        3, 1, 'win', 'home win', 0, 'lose', 5.0, 1.67, 3.75, 0],
#       dtype=object), array(['2008-11-08 00:00:00', 26, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492580, 10001, 'KVC Westerlo', 9987, 'KRC Genk', 1, 0,
#        'win', 'home win', 0, 'lose', 2.7, 2.6, 3.25, 0], dtype=object), array(['2015-12-18 00:00:00', 10023, 7809, 7809, 'Germany 1. Bundesliga',
#        '2015/2016', 2002237, 10189, 'FC Schalke 04', 8226,
#        'TSG 1899 Hoffenheim', 1, 0, 'win', 'home win', 0, 'lose', 1.67,
#        5.0, 4.0, 0], dtype=object), array(['2008-11-16 00:00:00', 28, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492582, 8342, 'Club Brugge KV', 8635,
#        'RSC Anderlecht', 1, 1, 'draw', 'draw', 2, 'draw', 2.3, 2.9, 3.25,
#        0], dtype=object), array(['2008-11-15 00:00:00', 29, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492583, 9987, 'KRC Genk', 9999, 'KSV Roeselare', 1, 1,
#        'draw', 'draw', 2, 'draw', 1.25, 10.0, 5.25, 0], dtype=object), array(['2008-11-15 00:00:00', 30, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492584, 10000, 'SV Zulte-Waregem', 9993,
#        'Beerschot AC', 2, 2, 'draw', 'draw', 2, 'draw', 2.0, 3.5, 3.25, 0],
#       dtype=object), array(['2008-11-16 00:00:00', 31, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492585, 9994, 'Sporting Lokeren', 9985,
#        'Standard de Liège', 1, 1, 'draw', 'draw', 2, 'draw', 3.25, 2.1,
#        3.25, 0], dtype=object), array(['2008-11-15 00:00:00', 32, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492586, 7947, 'FCV Dender EH', 8571, 'KV Kortrijk', 1,
#        0, 'win', 'home win', 0, 'lose', 2.3, 2.8, 3.25, 0], dtype=object), array(['2008-11-15 00:00:00', 33, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492587, 8203, 'KV Mechelen', 9998, 'RAEC Mons', 0, 0,
#        'draw', 'draw', 2, 'draw', 2.05, 3.4, 3.25, 0], dtype=object), array(['2008-11-15 00:00:00', 34, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492588, 9996, 'Royal Excel Mouscron', 9986,
#        'Sporting Charleroi', 2, 1, 'win', 'home win', 0, 'lose', 2.2, 3.0,
#        3.25, 0], dtype=object), array(['2008-11-15 00:00:00', 35, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492589, 4049, 'Tubize', 9984, 'KSV Cercle Brugge', 3,
#        0, 'win', 'home win', 0, 'lose', 4.33, 1.75, 3.4, 1], dtype=object), array(['2012-11-24 00:00:00', 14545, 13274, 13274,
#        'Netherlands Eredivisie', '2012/2013', 1222893, 10219,
#        'RKC Waalwijk', 8674, 'FC Groningen', 1, 1, 'draw', 'draw', 2,
#        'draw', 2.05, 3.4, 3.5, 0], dtype=object), array(['2008-11-22 00:00:00', 37, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492591, 8635, 'RSC Anderlecht', 10001, 'KVC Westerlo',
#        2, 0, 'win', 'home win', 0, 'lose', 1.44, 7.0, 4.33, 0],
#       dtype=object), array(['2008-11-22 00:00:00', 38, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492592, 9985, 'Standard de Liège', 9996,
#        'Royal Excel Mouscron', 3, 1, 'win', 'home win', 0, 'lose', 1.36,
#        9.0, 4.5, 0], dtype=object), array(['2010-08-22 00:00:00', 20217, 19694, 19694,
#        'Scotland Premier League', '2010/2011', 840236, 10251, 'Hibernian',
#        8548, 'Rangers', 0, 3, 'lose', 'away win', 1, 'win', 4.75, 1.73,
#        3.6, 1], dtype=object), array(['2012-01-08 00:00:00', 18408, 17642, 17642,
#        'Portugal Liga ZON Sagres', '2011/2012', 1042940, 9771,
#        'União de Leiria, SAD', 9772, 'SL Benfica', 0, 4, 'lose',
#        'away win', 1, 'win', 10.0, 1.3, 4.5, 1], dtype=object), array(['2008-11-22 00:00:00', 41, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492624, 9984, 'KSV Cercle Brugge', 8203,
#        'KV Mechelen', 2, 1, 'win', 'home win', 0, 'lose', 1.67, 5.5, 3.75,
#        0], dtype=object), array(['2011-12-03 00:00:00', 11454, 10257, 10257, 'Italy Serie A',
#        '2011/2012', 1083216, 9875, 'Napoli', 9888, 'Lecce', 4, 2, 'win',
#        'home win', 0, 'lose', 1.36, 9.0, 4.5, 0], dtype=object), array(['2008-11-22 00:00:00', 43, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492631, 9999, 'KSV Roeselare', 7947, 'FCV Dender EH',
#        2, 2, 'draw', 'draw', 2, 'draw', 2.4, 2.88, 3.3, 0], dtype=object), array(['2008-12-16 00:00:00', 44, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492636, 8571, 'KV Kortrijk', 10000,
#        'SV Zulte-Waregem', 1, 0, 'win', 'home win', 0, 'lose', 2.38, 2.88,
#        3.4, 0], dtype=object), array(['2008-11-22 00:00:00', 45, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492638, 9993, 'Beerschot AC', 9994,
#        'Sporting Lokeren', 0, 2, 'lose', 'away win', 1, 'win', 2.2, 3.3,
#        3.3, 0], dtype=object), array(['2008-11-30 00:00:00', 46, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492649, 8342, 'Club Brugge KV', 9993, 'Beerschot AC',
#        3, 0, 'win', 'home win', 0, 'lose', 1.44, 6.0, 4.2, 1],
#       dtype=object), array(['2008-11-29 00:00:00', 47, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492651, 9987, 'KRC Genk', 9984, 'KSV Cercle Brugge',
#        3, 2, 'win', 'home win', 0, 'lose', 1.73, 4.5, 3.4, 0],
#       dtype=object), array(['2008-11-29 00:00:00', 48, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492658, 10000, 'SV Zulte-Waregem', 9986,
#        'Sporting Charleroi', 4, 2, 'win', 'home win', 0, 'lose', 2.2, 3.0,
#        3.25, 0], dtype=object), array(['2009-04-19 00:00:00', 17784, 17642, 17642,
#        'Portugal Liga ZON Sagres', '2008/2009', 509327, 10215,
#        'Académica de Coimbra', 9773, 'FC Porto', 0, 3, 'lose', 'away win',
#        1, 'win', 5.5, 1.57, 3.6, 1], dtype=object), array(['2008-11-28 00:00:00', 50, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492664, 7947, 'FCV Dender EH', 8635, 'RSC Anderlecht',
#        0, 2, 'lose', 'away win', 1, 'win', 5.0, 1.67, 3.75, 0],
#       dtype=object), array(['2008-11-30 00:00:00', 51, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492666, 8203, 'KV Mechelen', 9985,
#        'Standard de Liège', 0, 0, 'draw', 'draw', 2, 'draw', 4.75, 1.67,
#        3.5, 0], dtype=object), array(['2008-11-29 00:00:00', 52, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492670, 9996, 'Royal Excel Mouscron', 9994,
#        'Sporting Lokeren', 2, 0, 'win', 'home win', 0, 'lose', 2.2, 3.0,
#        3.25, 0], dtype=object), array(['2008-11-29 00:00:00', 53, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492674, 4049, 'Tubize', 8571, 'KV Kortrijk', 3, 3,
#        'draw', 'draw', 2, 'draw', 2.3, 2.88, 3.2, 0], dtype=object), array(['2016-02-03 00:00:00', 7590, 4769, 4769, 'France Ligue 1',
#        '2015/2016', 1990111, 9747, 'En Avant de Guingamp', 10242,
#        'ES Troyes AC', 4, 0, 'win', 'home win', 0, 'lose', 1.62, 6.0, 3.8,
#        1], dtype=object), array(['2013-03-03 00:00:00', 14656, 13274, 13274,
#        'Netherlands Eredivisie', '2012/2013', 1223203, 10219,
#        'RKC Waalwijk', 10229, 'AZ', 2, 1, 'win', 'home win', 0, 'lose',
#        2.8, 2.4, 3.4, 0], dtype=object), array(['2008-12-06 00:00:00', 56, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492686, 9985, 'Standard de Liège', 10000,
#        'SV Zulte-Waregem', 1, 2, 'lose', 'away win', 1, 'win', 1.36, 7.5,
#        4.5, 0], dtype=object), array(['2008-12-06 00:00:00', 57, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492689, 9998, 'RAEC Mons', 7947, 'FCV Dender EH', 5,
#        2, 'win', 'home win', 0, 'lose', 2.1, 3.25, 3.25, 1], dtype=object), array(['2008-12-06 00:00:00', 58, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492692, 9986, 'Sporting Charleroi', 8203,
#        'KV Mechelen', 1, 2, 'lose', 'away win', 1, 'win', 1.67, 5.0, 3.4,
#        0], dtype=object), array(['2013-11-02 00:00:00', 9359, 7809, 7809, 'Germany 1. Bundesliga',
#        '2013/2014', 1479082, 8165, '1. FC Nürnberg', 8358, 'SC Freiburg',
#        0, 3, 'lose', 'away win', 1, 'win', 2.0, 3.75, 3.4, 1],
#       dtype=object), array(['2013-09-29 00:00:00', 12482, 10257, 10257, 'Italy Serie A',
#        '2013/2014', 1536577, 8686, 'Roma', 9857, 'Bologna', 5, 0, 'win',
#        'home win', 0, 'lose', 1.33, 9.0, 5.0, 1], dtype=object), array(['2011-11-26 00:00:00', 8779, 7809, 7809, 'Germany 1. Bundesliga',
#        '2011/2012', 1030084, 8406, 'FC Augsburg', 8721, 'VfL Wolfsburg',
#        2, 0, 'win', 'home win', 0, 'lose', 2.88, 2.38, 3.4, 0],
#       dtype=object), array(['2013-04-07 00:00:00', 12002, 10257, 10257, 'Italy Serie A',
#        '2012/2013', 1287274, 8551, 'Siena', 10167, 'Parma', 0, 0, 'draw',
#        'draw', 2, 'draw', 2.4, 3.1, 3.1, 0], dtype=object), array(['2012-03-24 00:00:00', 20525, 19694, 19694,
#        'Scotland Premier League', '2011/2012', 1024763, 8597,
#        'Kilmarnock', 9927, 'Motherwell', 2, 0, 'win', 'home win', 0,
#        'lose', 3.2, 2.25, 3.3, 0], dtype=object), array(['2008-12-14 00:00:00', 64, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492709, 8342, 'Club Brugge KV', 9985,
#        'Standard de Liège', 1, 4, 'lose', 'away win', 1, 'win', 2.62,
#        2.62, 3.2, 1], dtype=object), array(['2012-04-01 00:00:00', 18503, 17642, 17642,
#        'Portugal Liga ZON Sagres', '2011/2012', 1043027, 7844,
#        'Vitória Guimarães', 6403, 'FC Paços de Ferreira', 3, 1, 'win',
#        'home win', 0, 'lose', 2.05, 3.75, 3.25, 0], dtype=object), array(['2009-10-18 00:00:00', 13594, 13274, 13274,
#        'Netherlands Eredivisie', '2009/2010', 662333, 8614,
#        'Sparta Rotterdam', 10235, 'Feyenoord', 2, 1, 'win', 'home win', 0,
#        'lose', 5.0, 1.67, 3.4, 0], dtype=object), array(['2012-02-21 00:00:00', 11530, 10257, 10257, 'Italy Serie A',
#        '2011/2012', 1083354, 9857, 'Bologna', 8535, 'Fiorentina', 2, 0,
#        'win', 'home win', 0, 'lose', 2.5, 3.0, 3.0, 0], dtype=object), array(['2008-12-13 00:00:00', 68, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492722, 7947, 'FCV Dender EH', 9994,
#        'Sporting Lokeren', 1, 1, 'draw', 'draw', 2, 'draw', 3.25, 2.2,
#        3.25, 0], dtype=object), array(['2008-12-12 00:00:00', 69, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492724, 8203, 'KV Mechelen', 9993, 'Beerschot AC', 2,
#        1, 'win', 'home win', 0, 'lose', 2.5, 2.75, 3.3, 0], dtype=object), array(['2009-04-05 00:00:00', 7977, 7809, 7809, 'Germany 1. Bundesliga',
#        '2008/2009', 499548, 8722, '1. FC Köln', 8178,
#        'Bayer 04 Leverkusen', 0, 2, 'lose', 'away win', 1, 'win', 3.4,
#        2.1, 3.4, 0], dtype=object), array(['2012-03-25 00:00:00', 22896, 21518, 21518, 'Spain LIGA BBVA',
#        '2011/2012', 1051937, 8558, 'RCD Espanyol', 9864, 'Málaga CF', 1,
#        2, 'lose', 'away win', 1, 'win', 2.38, 3.0, 3.25, 0], dtype=object), array(['2008-12-13 00:00:00', 72, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492735, 10001, 'KVC Westerlo', 9984,
#        'KSV Cercle Brugge', 1, 2, 'lose', 'away win', 1, 'win', 2.05, 3.6,
#        3.3, 0], dtype=object), array(['2015-05-02 00:00:00', 12789, 10257, 10257, 'Italy Serie A',
#        '2014/2015', 1786345, 9882, 'Sampdoria', 9885, 'Juventus', 0, 1,
#        'lose', 'away win', 1, 'win', 3.0, 2.4, 3.3, 0], dtype=object), array(['2008-12-21 00:00:00', 74, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492745, 9985, 'Standard de Liège', 9991, 'KAA Gent',
#        2, 1, 'win', 'home win', 0, 'lose', 1.5, 6.5, 4.2, 0], dtype=object), array(['2008-12-20 00:00:00', 75, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492746, 9998, 'RAEC Mons', 10000, 'SV Zulte-Waregem',
#        2, 2, 'draw', 'draw', 2, 'draw', 2.25, 3.25, 3.25, 0], dtype=object), array(['2008-12-20 00:00:00', 76, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492749, 9986, 'Sporting Charleroi', 7947,
#        'FCV Dender EH', 2, 0, 'win', 'home win', 0, 'lose', 1.61, 5.5,
#        3.75, 0], dtype=object), array(['2008-12-20 00:00:00', 77, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492753, 9984, 'KSV Cercle Brugge', 9999,
#        'KSV Roeselare', 4, 3, 'win', 'home win', 0, 'lose', 1.4, 8.5,
#        4.33, 0], dtype=object), array(['2008-12-20 00:00:00', 78, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492757, 9994, 'Sporting Lokeren', 8203, 'KV Mechelen',
#        2, 2, 'draw', 'draw', 2, 'draw', 1.83, 4.5, 3.4, 0], dtype=object), array(['2008-12-20 00:00:00', 79, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492758, 9996, 'Royal Excel Mouscron', 8342,
#        'Club Brugge KV', 5, 1, 'win', 'home win', 0, 'lose', 3.0, 2.4,
#        3.25, 1], dtype=object), array(['2008-12-21 00:00:00', 80, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492760, 8571, 'KV Kortrijk', 10001, 'KVC Westerlo', 0,
#        0, 'draw', 'draw', 2, 'draw', 2.3, 3.2, 3.25, 0], dtype=object), array(['2008-12-20 00:00:00', 81, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492763, 9993, 'Beerschot AC', 4049, 'Tubize', 2, 0,
#        'win', 'home win', 0, 'lose', 1.57, 6.0, 3.8, 0], dtype=object), array(['2009-01-18 00:00:00', 82, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492769, 9993, 'Beerschot AC', 9987, 'KRC Genk', 4, 1,
#        'win', 'home win', 0, 'lose', 2.6, 2.62, 3.3, 1], dtype=object), array(['2012-01-29 00:00:00', 14288, 13274, 13274,
#        'Netherlands Eredivisie', '2011/2012', 1028696, 10219,
#        'RKC Waalwijk', 9839, 'VVV-Venlo', 4, 0, 'win', 'home win', 0,
#        'lose', 1.62, 5.0, 4.0, 1], dtype=object), array(['2009-01-16 00:00:00', 84, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492775, 8635, 'RSC Anderlecht', 9984,
#        'KSV Cercle Brugge', 1, 2, 'lose', 'away win', 1, 'win', 1.36, 9.0,
#        4.5, 0], dtype=object), array(['2009-01-17 00:00:00', 85, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492779, 9998, 'RAEC Mons', 9991, 'KAA Gent', 1, 2,
#        'lose', 'away win', 1, 'win', 2.8, 2.3, 3.3, 0], dtype=object), array(['2009-01-17 00:00:00', 86, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492781, 9985, 'Standard de Liège', 7947,
#        'FCV Dender EH', 3, 2, 'win', 'home win', 0, 'lose', 1.2, 13.0,
#        6.5, 0], dtype=object), array(['2010-09-12 00:00:00', 11129, 10257, 10257, 'Italy Serie A',
#        '2010/2011', 888172, 8543, 'Lazio', 9857, 'Bologna', 3, 1, 'win',
#        'home win', 0, 'lose', 1.73, 5.25, 3.4, 0], dtype=object), array(['2009-01-17 00:00:00', 88, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492785, 8571, 'KV Kortrijk', 9999, 'KSV Roeselare', 2,
#        1, 'win', 'home win', 0, 'lose', 1.67, 4.75, 3.5, 0], dtype=object), array(['2009-01-17 00:00:00', 89, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492789, 9996, 'Royal Excel Mouscron', 4049, 'Tubize',
#        1, 1, 'draw', 'draw', 2, 'draw', 1.45, 6.5, 3.8, 0], dtype=object), array(['2009-01-18 00:00:00', 90, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492792, 9986, 'Sporting Charleroi', 10001,
#        'KVC Westerlo', 1, 2, 'lose', 'away win', 1, 'win', 2.1, 3.5, 3.3,
#        0], dtype=object), array(['2015-12-20 00:00:00', 15493, 13274, 13274,
#        'Netherlands Eredivisie', '2015/2016', 1983421, 10218, 'Excelsior',
#        7788, 'SC Cambuur', 1, 4, 'lose', 'away win', 1, 'win', 1.95, 3.75,
#        3.5, 1], dtype=object), array(['2009-02-18 00:00:00', 92, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492801, 9991, 'KAA Gent', 8635, 'RSC Anderlecht', 1,
#        2, 'lose', 'away win', 1, 'win', 3.0, 2.2, 3.3, 0], dtype=object), array(['2009-01-25 00:00:00', 93, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492804, 10001, 'KVC Westerlo', 9985,
#        'Standard de Liège', 0, 1, 'lose', 'away win', 1, 'win', 3.4, 2.0,
#        3.25, 0], dtype=object), array(['2012-04-28 00:00:00', 20547, 19694, 19694,
#        'Scotland Premier League', '2011/2012', 1189722, 9927,
#        'Motherwell', 8467, 'St. Johnstone FC', 5, 1, 'win', 'home win', 0,
#        'lose', 2.1, 3.5, 3.3, 1], dtype=object), array(['2009-01-24 00:00:00', 95, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492807, 9999, 'KSV Roeselare', 9986,
#        'Sporting Charleroi', 3, 1, 'win', 'home win', 0, 'lose', 2.7, 2.4,
#        3.2, 0], dtype=object), array(['2009-10-25 00:00:00', 11009, 10257, 10257, 'Italy Serie A',
#        '2009/2010', 704523, 8529, 'Cagliari', 10233, 'Genoa', 3, 2, 'win',
#        'home win', 0, 'lose', 2.75, 2.75, 3.0, 0], dtype=object), array(['2009-01-24 00:00:00', 97, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492814, 8203, 'KV Mechelen', 9996,
#        'Royal Excel Mouscron', 2, 2, 'draw', 'draw', 2, 'draw', 2.3, 2.8,
#        3.25, 0], dtype=object), array(['2011-05-21 00:00:00', 22594, 21518, 21518, 'Spain LIGA BBVA',
#        '2010/2011', 875456, 9864, 'Málaga CF', 8634, 'FC Barcelona', 1, 3,
#        'lose', 'away win', 1, 'win', 3.25, 2.1, 3.5, 0], dtype=object), array(['2009-01-24 00:00:00', 99, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492819, 7947, 'FCV Dender EH', 9993, 'Beerschot AC',
#        0, 1, 'lose', 'away win', 1, 'win', 3.2, 2.1, 3.25, 0],
#       dtype=object), array(['2010-01-13 00:00:00', 19965, 19694, 19694,
#        'Scotland Premier League', '2009/2010', 658890, 8429,
#        'Hamilton Academical FC', 9938, 'Dundee United', 0, 1, 'lose',
#        'away win', 1, 'win', 2.88, 2.4, 3.3, 0], dtype=object), array(['2008-08-23 00:00:00', 101, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492483, 8635, 'RSC Anderlecht', 9991, 'KAA Gent', 2,
#        2, 'draw', 'draw', 2, 'draw', 1.65, 5.0, 3.4, 0], dtype=object), array(['2008-08-23 00:00:00', 102, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492484, 9985, 'Standard de Liège', 10001,
#        'KVC Westerlo', 3, 0, 'win', 'home win', 0, 'lose', 1.33, 10.0,
#        4.2, 1], dtype=object), array(['2014-12-07 00:00:00', 19115, 17642, 17642,
#        'Portugal Liga ZON Sagres', '2014/2015', 1748822, 8348,
#        'Moreirense FC', 6403, 'FC Paços de Ferreira', 2, 0, 'win',
#        'home win', 0, 'lose', 2.75, 2.63, 3.1, 0], dtype=object), array(['2008-10-26 00:00:00', 17853, 17642, 17642,
#        'Portugal Liga ZON Sagres', '2008/2009', 509172, 10212,
#        'CS Marítimo', 7841, 'Rio Ave FC', 1, 1, 'draw', 'draw', 2, 'draw',
#        1.73, 4.5, 3.4, 0], dtype=object), array(['2014-11-07 00:00:00', 19091, 17642, 17642,
#        'Portugal Liga ZON Sagres', '2014/2015', 1748798, 158085,
#        'FC Arouca', 7844, 'Vitória Guimarães', 1, 2, 'lose', 'away win',
#        1, 'win', 3.0, 2.38, 3.25, 0], dtype=object), array(['2008-08-23 00:00:00', 106, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492488, 9996, 'Royal Excel Mouscron', 8203,
#        'KV Mechelen', 3, 1, 'win', 'home win', 0, 'lose', 2.05, 3.4, 3.3,
#        0], dtype=object), array(['2008-08-23 00:00:00', 107, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492489, 8571, 'KV Kortrijk', 9984,
#        'KSV Cercle Brugge', 2, 1, 'win', 'home win', 0, 'lose', 3.0, 2.2,
#        3.25, 0], dtype=object), array(['2011-04-10 00:00:00', 11272, 10257, 10257, 'Italy Serie A',
#        '2010/2011', 888475, 9885, 'Juventus', 10233, 'Genoa', 3, 2, 'win',
#        'home win', 0, 'lose', 1.57, 6.5, 3.6, 0], dtype=object), array(['2011-09-26 00:00:00', 18570, 17642, 17642,
#        'Portugal Liga ZON Sagres', '2011/2012', 1042870, 10215,
#        'Académica de Coimbra', 4064, 'Feirense', 4, 0, 'win', 'home win',
#        0, 'lose', 2.05, 3.75, 3.2, 1], dtype=object), array(['2014-04-21 00:00:00', 19004, 17642, 17642,
#        'Portugal Liga ZON Sagres', '2013/2014', 1498316, 9773, 'FC Porto',
#        7841, 'Rio Ave FC', 3, 0, 'win', 'home win', 0, 'lose', 1.25, 15.0,
#        5.0, 1], dtype=object), array(['2009-02-14 00:00:00', 17716, 17642, 17642,
#        'Portugal Liga ZON Sagres', '2008/2009', 509267, 10212,
#        'CS Marítimo', 10213, 'Amadora', 1, 0, 'win', 'home win', 0,
#        'lose', 1.72, 4.75, 3.25, 0], dtype=object), array(['2009-02-01 00:00:00', 112, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492847, 9986, 'Sporting Charleroi', 9991, 'KAA Gent',
#        2, 5, 'lose', 'away win', 1, 'win', 2.6, 2.5, 3.25, 1],
#       dtype=object), array(['2008-12-06 00:00:00', 7875, 7809, 7809, 'Germany 1. Bundesliga',
#        '2008/2009', 499455, 9810, 'Eintracht Frankfurt', 9911,
#        'VfL Bochum', 4, 0, 'win', 'home win', 0, 'lose', 2.1, 3.5, 3.3, 1],
#       dtype=object), array(['2009-04-19 00:00:00', 10511, 10257, 10257, 'Italy Serie A',
#        '2008/2009', 539873, 8540, 'Palermo', 9857, 'Bologna', 4, 1, 'win',
#        'home win', 0, 'lose', 1.73, 5.5, 3.4, 1], dtype=object), array(['2012-04-28 00:00:00', 18524, 17642, 17642,
#        'Portugal Liga ZON Sagres', '2011/2012', 1043048, 10212,
#        'CS Marítimo', 9773, 'FC Porto', 0, 2, 'lose', 'away win', 1,
#        'win', 7.0, 1.5, 4.0, 0], dtype=object), array(['2015-05-03 00:00:00', 12794, 10257, 10257, 'Italy Serie A',
#        '2014/2015', 1786350, 9876, 'Hellas Verona', 8600, 'Udinese', 0, 1,
#        'lose', 'away win', 1, 'win', 2.1, 3.4, 3.6, 0], dtype=object), array(['2009-01-31 00:00:00', 117, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492858, 9993, 'Beerschot AC', 10001, 'KVC Westerlo',
#        2, 1, 'win', 'home win', 0, 'lose', 1.9, 3.6, 3.3, 0], dtype=object), array(['2009-02-07 00:00:00', 118, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492989, 7947, 'FCV Dender EH', 8342, 'Club Brugge KV',
#        0, 2, 'lose', 'away win', 1, 'win', 4.33, 1.72, 3.4, 0],
#       dtype=object), array(['2009-02-06 00:00:00', 119, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492990, 8571, 'KV Kortrijk', 9985,
#        'Standard de Liège', 0, 2, 'lose', 'away win', 1, 'win', 5.0, 1.66,
#        3.75, 0], dtype=object), array(['2009-02-07 00:00:00', 120, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492991, 8635, 'RSC Anderlecht', 9998, 'RAEC Mons', 3,
#        2, 'win', 'home win', 0, 'lose', 1.2, 13.0, 5.5, 0], dtype=object), array(['2009-02-07 00:00:00', 121, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492992, 9987, 'KRC Genk', 10000, 'SV Zulte-Waregem',
#        1, 2, 'lose', 'away win', 1, 'win', 1.66, 4.75, 3.4, 0],
#       dtype=object), array(['2011-03-20 00:00:00', 11252, 10257, 10257, 'Italy Serie A',
#        '2010/2011', 888455, 9857, 'Bologna', 10233, 'Genoa', 1, 1, 'draw',
#        'draw', 2, 'draw', 2.6, 3.1, 2.8, 0], dtype=object), array(['2015-05-03 00:00:00', 24078, 21518, 21518, 'Spain LIGA BBVA',
#        '2014/2015', 1778374, 9864, 'Málaga CF', 10268, 'Elche CF', 1, 2,
#        'lose', 'away win', 1, 'win', 1.62, 6.0, 3.8, 0], dtype=object), array(['2016-03-12 00:00:00', 10117, 7809, 7809, 'Germany 1. Bundesliga',
#        '2015/2016', 2002322, 9904, 'Hannover 96', 8722, '1. FC Köln', 0,
#        2, 'lose', 'away win', 1, 'win', 3.5, 2.15, 3.3, 0], dtype=object), array(['2009-04-26 00:00:00', 10525, 10257, 10257, 'Italy Serie A',
#        '2008/2009', 539887, 9804, 'Torino', 8551, 'Siena', 1, 0, 'win',
#        'home win', 0, 'lose', 1.8, 5.0, 3.2, 0], dtype=object), array(['2012-12-01 00:00:00', 23090, 21518, 21518, 'Spain LIGA BBVA',
#        '2012/2013', 1260253, 8305, 'Getafe CF', 9864, 'Málaga CF', 1, 0,
#        'win', 'home win', 0, 'lose', 2.6, 2.7, 3.25, 0], dtype=object), array(['2014-09-14 00:00:00', 19338, 17642, 17642,
#        'Portugal Liga ZON Sagres', '2014/2015', 1748748, 10212,
#        'CS Marítimo', 6547, 'FC Penafiel', 2, 0, 'win', 'home win', 0,
#        'lose', 1.67, 5.25, 3.6, 0], dtype=object), array(['2013-09-25 00:00:00', 12468, 10257, 10257, 'Italy Serie A',
#        '2013/2014', 1536563, 8543, 'Lazio', 8530, 'Catania', 3, 1, 'win',
#        'home win', 0, 'lose', 1.57, 6.0, 3.75, 0], dtype=object), array(['2009-02-14 00:00:00', 129, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 493000, 9993, 'Beerschot AC', 9984,
#        'KSV Cercle Brugge', 1, 1, 'draw', 'draw', 2, 'draw', 2.15, 3.1,
#        3.3, 0], dtype=object), array(['2009-02-14 00:00:00', 130, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 493001, 8203, 'KV Mechelen', 9991, 'KAA Gent', 3, 3,
#        'draw', 'draw', 2, 'draw', 2.7, 2.37, 3.3, 0], dtype=object), array(['2010-04-03 00:00:00', 8311, 7809, 7809, 'Germany 1. Bundesliga',
#        '2009/2010', 674534, 8722, '1. FC Köln', 8177, 'Hertha BSC Berlin',
#        0, 3, 'lose', 'away win', 1, 'win', 2.38, 3.0, 3.25, 1],
#       dtype=object), array(['2010-04-24 00:00:00', 18045, 17642, 17642,
#        'Portugal Liga ZON Sagres', '2009/2010', 686301, 9772,
#        'SL Benfica', 2033, 'S.C. Olhanense', 5, 0, 'win', 'home win', 0,
#        'lose', 1.17, 17.0, 6.5, 1], dtype=object), array(['2009-02-14 00:00:00', 133, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 493004, 9998, 'RAEC Mons', 8571, 'KV Kortrijk', 1, 1,
#        'draw', 'draw', 2, 'draw', 2.1, 3.2, 3.3, 0], dtype=object), array(['2009-02-14 00:00:00', 134, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 493005, 9985, 'Standard de Liège', 4049, 'Tubize', 4,
#        0, 'win', 'home win', 0, 'lose', 1.22, 10.0, 5.75, 1], dtype=object), array(['2015-02-23 00:00:00', 12682, 10257, 10257, 'Italy Serie A',
#        '2014/2015', 1786248, 9875, 'Napoli', 7943, 'Sassuolo', 2, 0,
#        'win', 'home win', 0, 'lose', 1.5, 7.5, 4.0, 0], dtype=object), array(['2010-08-21 00:00:00', 18214, 17642, 17642,
#        'Portugal Liga ZON Sagres', '2010/2011', 859657, 10238,
#        'Vitória Setúbal', 10264, 'SC Braga', 0, 0, 'draw', 'draw', 2,
#        'draw', 5.25, 1.7, 3.4, 0], dtype=object), array(['2014-04-19 00:00:00', 12414, 10257, 10257, 'Italy Serie A',
#        '2013/2014', 1536859, 8543, 'Lazio', 9804, 'Torino', 3, 3, 'draw',
#        'draw', 2, 'draw', 1.8, 4.75, 3.3, 0], dtype=object), array(['2016-04-24 00:00:00', 13177, 10257, 10257, 'Italy Serie A',
#        '2015/2016', 2060577, 8535, 'Fiorentina', 9885, 'Juventus', 1, 2,
#        'lose', 'away win', 1, 'win', 3.5, 2.15, 3.3, 0], dtype=object), array(['2009-02-21 00:00:00', 139, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 493010, 4049, 'Tubize', 10000, 'SV Zulte-Waregem', 0,
#        6, 'lose', 'away win', 1, 'win', 3.0, 2.2, 3.2, 1], dtype=object), array(['2009-02-21 00:00:00', 140, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 493011, 8571, 'KV Kortrijk', 9986,
#        'Sporting Charleroi', 1, 1, 'draw', 'draw', 2, 'draw', 2.1, 3.1,
#        3.4, 0], dtype=object), array(['2013-05-05 00:00:00', 12043, 10257, 10257, 'Italy Serie A',
#        '2012/2013', 1287315, 8530, 'Catania', 8551, 'Siena', 3, 0, 'win',
#        'home win', 0, 'lose', 2.25, 3.2, 3.25, 1], dtype=object), array(['2009-03-14 00:00:00', 19824, 19694, 19694,
#        'Scotland Premier League', '2008/2009', 490153, 8066,
#        'Inverness Caledonian Thistle', 8597, 'Kilmarnock', 2, 1, 'win',
#        'home win', 0, 'lose', 2.1, 3.4, 3.4, 0], dtype=object), array(['2008-12-14 00:00:00', 10331, 10257, 10257, 'Italy Serie A',
#        '2008/2009', 539711, 8686, 'Roma', 8529, 'Cagliari', 3, 2, 'win',
#        'home win', 0, 'lose', 1.4, 11.0, 3.8, 0], dtype=object), array(['2009-02-21 00:00:00', 144, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 493015, 9991, 'KAA Gent', 9993, 'Beerschot AC', 1, 3,
#        'lose', 'away win', 1, 'win', 1.66, 5.0, 3.4, 0], dtype=object), array(['2013-02-10 00:00:00', 18681, 17642, 17642,
#        'Portugal Liga ZON Sagres', '2012/2013', 1256185, 10238,
#        'Vitória Setúbal', 9764, 'Gil Vicente FC', 1, 0, 'win', 'home win',
#        0, 'lose', 2.38, 3.0, 3.2, 0], dtype=object), array(['2009-01-31 00:00:00', 17705, 17642, 17642,
#        'Portugal Liga ZON Sagres', '2008/2009', 509256, 7992, 'Trofense',
#        9768, 'Sporting CP', 0, 0, 'draw', 'draw', 2, 'draw', 5.5, 1.53,
#        3.6, 0], dtype=object), array(['2014-12-17 00:00:00', 15163, 13274, 13274,
#        'Netherlands Eredivisie', '2014/2015', 1712519, 8640, 'PSV', 10235,
#        'Feyenoord', 4, 3, 'win', 'home win', 0, 'lose', 1.75, 4.2, 4.0, 0],
#       dtype=object), array(['2009-03-01 00:00:00', 148, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 493019, 9985, 'Standard de Liège', 9984,
#        'KSV Cercle Brugge', 4, 0, 'win', 'home win', 0, 'lose', 1.44, 7.5,
#        3.75, 1], dtype=object), array(['2009-03-01 00:00:00', 149, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 493020, 9994, 'Sporting Lokeren', 9991, 'KAA Gent', 0,
#        1, 'lose', 'away win', 1, 'win', 2.62, 2.45, 3.25, 0], dtype=object), array(['2016-01-02 00:00:00', 21377, 19694, 19694,
#        'Scotland Premier League', '2015/2016', 1990972, 8597,
#        'Kilmarnock', 9860, 'Heart of Midlothian', 2, 2, 'draw', 'draw', 2,
#        'draw', 4.5, 1.73, 3.8, 0], dtype=object), array(['2010-12-04 00:00:00', 22331, 21518, 21518, 'Spain LIGA BBVA',
#        '2010/2011', 875718, 8633, 'Real Madrid CF', 10267, 'Valencia CF',
#        2, 0, 'win', 'home win', 0, 'lose', 1.4, 7.5, 4.5, 0], dtype=object), array(['2013-03-16 00:00:00', 11974, 10257, 10257, 'Italy Serie A',
#        '2012/2013', 1287256, 8530, 'Catania', 8600, 'Udinese', 3, 1,
#        'win', 'home win', 0, 'lose', 1.91, 4.0, 3.4, 0], dtype=object), array(['2013-02-27 00:00:00', 20733, 19694, 19694,
#        'Scotland Premier League', '2012/2013', 1230386, 8284, 'Dundee FC',
#        8467, 'St. Johnstone FC', 2, 2, 'draw', 'draw', 2, 'draw', 4.2,
#        1.91, 3.3, 0], dtype=object), array(['2009-03-08 00:00:00', 154, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 493025, 9984, 'KSV Cercle Brugge', 8342,
#        'Club Brugge KV', 1, 3, 'lose', 'away win', 1, 'win', 2.8, 2.37,
#        3.2, 0], dtype=object), array(['2009-03-06 00:00:00', 155, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 493026, 9998, 'RAEC Mons', 9985, 'Standard de Liège',
#        0, 1, 'lose', 'away win', 1, 'win', 6.5, 1.57, 3.6, 0],
#       dtype=object), array(['2009-03-07 00:00:00', 156, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 493027, 8635, 'RSC Anderlecht', 10000,
#        'SV Zulte-Waregem', 2, 0, 'win', 'home win', 0, 'lose', 1.4, 8.0,
#        4.5, 0], dtype=object), array(['2009-03-07 00:00:00', 157, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 493028, 8571, 'KV Kortrijk', 9994, 'Sporting Lokeren',
#        2, 3, 'lose', 'away win', 1, 'win', 2.4, 3.1, 3.1, 0], dtype=object), array(['2009-03-07 00:00:00', 158, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 493029, 9987, 'KRC Genk', 7947, 'FCV Dender EH', 4, 3,
#        'win', 'home win', 0, 'lose', 1.4, 8.0, 4.5, 0], dtype=object), array(['2009-03-08 00:00:00', 159, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 493030, 10001, 'KVC Westerlo', 8203, 'KV Mechelen', 0,
#        1, 'lose', 'away win', 1, 'win', 1.8, 4.2, 3.4, 0], dtype=object), array(['2011-10-03 00:00:00', 18581, 17642, 17642,
#        'Portugal Liga ZON Sagres', '2011/2012', 1042881, 9764,
#        'Gil Vicente FC', 10211, 'SC Beira Mar', 0, 0, 'draw', 'draw', 2,
#        'draw', 2.1, 3.6, 3.25, 0], dtype=object), array(['2009-03-07 00:00:00', 161, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 493032, 9991, 'KAA Gent', 4049, 'Tubize', 2, 0, 'win',
#        'home win', 0, 'lose', 1.28, 9.5, 5.5, 0], dtype=object), array(['2012-03-31 00:00:00', 11610, 10257, 10257, 'Italy Serie A',
#        '2011/2012', 1083260, 10167, 'Parma', 8543, 'Lazio', 3, 1, 'win',
#        'home win', 0, 'lose', 2.5, 3.0, 3.0, 0], dtype=object), array(['2009-03-13 00:00:00', 163, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 493034, 8203, 'KV Mechelen', 8635, 'RSC Anderlecht',
#        2, 1, 'win', 'home win', 0, 'lose', 4.5, 1.75, 3.6, 0],
#       dtype=object), array(['2009-02-14 00:00:00', 19797, 19694, 19694,
#        'Scotland Premier League', '2008/2009', 490126, 9938,
#        'Dundee United', 8066, 'Inverness Caledonian Thistle', 1, 1,
#        'draw', 'draw', 2, 'draw', 1.66, 5.5, 3.6, 0], dtype=object), array(['2009-03-14 00:00:00', 165, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 493036, 9993, 'Beerschot AC', 9998, 'RAEC Mons', 2, 0,
#        'win', 'home win', 0, 'lose', 2.412, 4.31, 3.751, 0], dtype=object), array(['2009-03-14 00:00:00', 166, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 493037, 9994, 'Sporting Lokeren', 9986,
#        'Sporting Charleroi', 0, 0, 'draw', 'draw', 2, 'draw', 2.1, 3.6,
#        3.25, 0], dtype=object), array(['2009-03-14 00:00:00', 167, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 493038, 7947, 'FCV Dender EH', 9984,
#        'KSV Cercle Brugge', 1, 0, 'win', 'home win', 0, 'lose', 2.88,
#        2.38, 3.4, 0], dtype=object), array(['2009-03-15 00:00:00', 168, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 493039, 8342, 'Club Brugge KV', 9991, 'KAA Gent', 1,
#        4, 'lose', 'away win', 1, 'win', 1.8, 4.0, 3.4, 1], dtype=object), array(['2015-08-15 00:00:00', 19388, 17642, 17642,
#        'Portugal Liga ZON Sagres', '2015/2016', 2015809, 9807,
#        'CF Os Belenenses', 7841, 'Rio Ave FC', 3, 3, 'draw', 'draw', 2,
#        'draw', 2.45, 3.0, 3.1, 0], dtype=object), array(['2011-12-17 00:00:00', 18398, 17642, 17642,
#        'Portugal Liga ZON Sagres', '2011/2012', 1042930, 7844,
#        'Vitória Guimarães', 9764, 'Gil Vicente FC', 1, 1, 'draw', 'draw',
#        2, 'draw', 1.73, 4.75, 3.6, 0], dtype=object), array(['2009-03-14 00:00:00', 171, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 493042, 4049, 'Tubize', 10001, 'KVC Westerlo', 1, 2,
#        'lose', 'away win', 1, 'win', 4.33, 1.8, 3.6, 0], dtype=object), array(['2009-03-20 00:00:00', 172, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 493043, 8571, 'KV Kortrijk', 8342, 'Club Brugge KV',
#        2, 3, 'lose', 'away win', 1, 'win', 3.75, 2.0, 3.3, 0],
#       dtype=object), array(['2010-10-24 00:00:00', 11382, 10257, 10257, 'Italy Serie A',
#        '2010/2011', 888235, 8543, 'Lazio', 8529, 'Cagliari', 2, 1, 'win',
#        'home win', 0, 'lose', 1.73, 5.0, 3.5, 0], dtype=object), array(['2012-12-07 00:00:00', 23101, 21518, 21518, 'Spain LIGA BBVA',
#        '2012/2013', 1260230, 8558, 'RCD Espanyol', 8302, 'Sevilla FC', 2,
#        2, 'draw', 'draw', 2, 'draw', 2.8, 2.5, 3.3, 0], dtype=object), array(['2009-04-18 00:00:00', 7996, 7809, 7809, 'Germany 1. Bundesliga',
#        '2008/2009', 499567, 9911, 'VfL Bochum', 9789, 'Borussia Dortmund',
#        0, 2, 'lose', 'away win', 1, 'win', 3.1, 2.3, 3.4, 0], dtype=object), array(['2009-03-21 00:00:00', 176, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 493047, 10001, 'KVC Westerlo', 7947, 'FCV Dender EH',
#        3, 1, 'win', 'home win', 0, 'lose', 1.57, 5.25, 3.75, 0],
#       dtype=object), array(['2009-03-21 00:00:00', 177, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 493048, 9999, 'KSV Roeselare', 8203, 'KV Mechelen', 1,
#        0, 'win', 'home win', 0, 'lose', 2.2, 3.0, 3.3, 0], dtype=object), array(['2015-08-15 00:00:00', 15516, 13274, 13274,
#        'Netherlands Eredivisie', '2015/2016', 1983282, 8526,
#        'De Graafschap', 6413, 'PEC Zwolle', 0, 3, 'lose', 'away win', 1,
#        'win', 2.6, 2.5, 3.6, 1], dtype=object), array(['2009-03-21 00:00:00', 179, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 493050, 9987, 'KRC Genk', 4049, 'Tubize', 3, 0, 'win',
#        'home win', 0, 'lose', 1.22, 11.0, 5.5, 1], dtype=object), array(['2009-03-21 00:00:00', 180, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 493051, 8635, 'RSC Anderlecht', 9993, 'Beerschot AC',
#        2, 0, 'win', 'home win', 0, 'lose', 1.4, 7.0, 4.0, 0], dtype=object), array(['2011-11-05 00:00:00', 14220, 13274, 13274,
#        'Netherlands Eredivisie', '2011/2012', 1028589, 9761, 'NAC Breda',
#        8277, 'Vitesse', 1, 0, 'win', 'home win', 0, 'lose', 2.7, 2.5, 3.4,
#        0], dtype=object), array(['2009-04-04 00:00:00', 182, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 493053, 9996, 'Royal Excel Mouscron', 9998,
#        'RAEC Mons', 3, 2, 'win', 'home win', 0, 'lose', 1.9, 4.2, 3.3, 0],
#       dtype=object), array(['2011-01-23 00:00:00', 22404, 21518, 21518, 'Spain LIGA BBVA',
#        '2010/2011', 875836, 8305, 'Getafe CF', 8558, 'RCD Espanyol', 1, 3,
#        'lose', 'away win', 1, 'win', 2.1, 3.5, 3.3, 0], dtype=object), array(['2009-04-04 00:00:00', 184, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 493055, 10000, 'SV Zulte-Waregem', 9984,
#        'KSV Cercle Brugge', 3, 1, 'win', 'home win', 0, 'lose', 2.0, 3.6,
#        3.4, 0], dtype=object), array(['2015-08-08 00:00:00', 15418, 13274, 13274,
#        'Netherlands Eredivisie', '2015/2016', 1983274, 9803,
#        'Roda JC Kerkrade', 9791, 'Heracles Almelo', 3, 1, 'win',
#        'home win', 0, 'lose', 2.15, 3.2, 3.5, 0], dtype=object), array(['2016-04-16 00:00:00', 19603, 17642, 17642,
#        'Portugal Liga ZON Sagres', '2015/2016', 2016078, 8348,
#        'Moreirense FC', 9768, 'Sporting CP', 0, 1, 'lose', 'away win', 1,
#        'win', 13.0, 1.25, 5.25, 0], dtype=object), array(['2009-04-04 00:00:00', 187, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 493058, 8203, 'KV Mechelen', 8571, 'KV Kortrijk', 1,
#        1, 'draw', 'draw', 2, 'draw', 1.85, 4.2, 3.5, 0], dtype=object), array(['2016-03-11 00:00:00', 10118, 7809, 7809, 'Germany 1. Bundesliga',
#        '2015/2016', 2002323, 8177, 'Hertha BSC Berlin', 10189,
#        'FC Schalke 04', 2, 0, 'win', 'home win', 0, 'lose', 2.4, 3.0, 3.2,
#        0], dtype=object), array(['2016-04-17 00:00:00', 13158, 10257, 10257, 'Italy Serie A',
#        '2015/2016', 2060538, 9882, 'Sampdoria', 8564, 'Milan', 0, 1,
#        'lose', 'away win', 1, 'win', 3.0, 2.4, 3.3, 0], dtype=object), array(['2009-04-12 00:00:00', 190, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 493061, 8635, 'RSC Anderlecht', 8342,
#        'Club Brugge KV', 1, 0, 'win', 'home win', 0, 'lose', 1.67, 5.0,
#        3.5, 0], dtype=object), array(['2009-04-10 00:00:00', 191, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 493062, 9999, 'KSV Roeselare', 9987, 'KRC Genk', 1, 0,
#        'win', 'home win', 0, 'lose', 3.2, 2.25, 3.25, 0], dtype=object), array(['2009-04-11 00:00:00', 192, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 493063, 9993, 'Beerschot AC', 10000,
#        'SV Zulte-Waregem', 1, 2, 'lose', 'away win', 1, 'win', 1.91, 4.0,
#        3.5, 0], dtype=object), array(['2009-04-11 00:00:00', 193, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 493064, 9985, 'Standard de Liège', 9994,
#        'Sporting Lokeren', 1, 0, 'win', 'home win', 0, 'lose', 1.33, 10.0,
#        4.75, 0], dtype=object), array(['2009-04-11 00:00:00', 194, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 493065, 8571, 'KV Kortrijk', 7947, 'FCV Dender EH', 1,
#        2, 'lose', 'away win', 1, 'win', 2.0, 3.8, 3.3, 0], dtype=object), array(['2009-04-11 00:00:00', 195, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 493066, 9998, 'RAEC Mons', 8203, 'KV Mechelen', 0, 1,
#        'lose', 'away win', 1, 'win', 2.25, 3.2, 3.3, 0], dtype=object), array(['2009-04-11 00:00:00', 196, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 493067, 9986, 'Sporting Charleroi', 9996,
#        'Royal Excel Mouscron', 1, 0, 'win', 'home win', 0, 'lose', 1.95,
#        3.8, 3.4, 0], dtype=object), array(['2015-08-28 00:00:00', 15668, 13274, 13274,
#        'Netherlands Eredivisie', '2015/2016', 1983299, 8525, 'Willem II',
#        8464, 'N.E.C.', 0, 1, 'lose', 'away win', 1, 'win', 1.83, 4.2, 3.5,
#        0], dtype=object), array(['2009-04-12 00:00:00', 198, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 493069, 9991, 'KAA Gent', 10001, 'KVC Westerlo', 2, 0,
#        'win', 'home win', 0, 'lose', 1.8, 4.2, 3.3, 0], dtype=object), array(['2008-08-30 00:00:00', 199, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492491, 8635, 'RSC Anderlecht', 8571, 'KV Kortrijk',
#        4, 0, 'win', 'home win', 0, 'lose', 1.29, 9.0, 4.75, 1],
#       dtype=object), array(['2008-08-30 00:00:00', 200, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492492, 9987, 'KRC Genk', 9994, 'Sporting Lokeren', 1,
#        0, 'win', 'home win', 0, 'lose', 1.62, 5.5, 3.4, 0], dtype=object), array(['2012-02-19 00:00:00', 8854, 7809, 7809, 'Germany 1. Bundesliga',
#        '2011/2012', 1030257, 10189, 'FC Schalke 04', 8721,
#        'VfL Wolfsburg', 4, 0, 'win', 'home win', 0, 'lose', 1.67, 5.0,
#        3.75, 1], dtype=object), array(['2008-08-31 00:00:00', 202, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492494, 9991, 'KAA Gent', 9986, 'Sporting Charleroi',
#        2, 0, 'win', 'home win', 0, 'lose', 1.62, 5.0, 3.5, 0],
#       dtype=object), array(['2008-08-30 00:00:00', 203, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492495, 7947, 'FCV Dender EH', 9996,
#        'Royal Excel Mouscron', 1, 2, 'lose', 'away win', 1, 'win', 2.5,
#        2.5, 3.3, 0], dtype=object), array(['2008-10-04 00:00:00', 13536, 13274, 13274,
#        'Netherlands Eredivisie', '2008/2009', 523687, 8277, 'Vitesse',
#        8525, 'Willem II', 2, 2, 'draw', 'draw', 2, 'draw', 2.05, 3.4,
#        3.25, 0], dtype=object), array(['2008-08-31 00:00:00', 205, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492497, 9999, 'KSV Roeselare', 9985,
#        'Standard de Liège', 1, 1, 'draw', 'draw', 2, 'draw', 5.5, 1.57,
#        3.6, 0], dtype=object), array(['2008-08-29 00:00:00', 206, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492498, 4049, 'Tubize', 8342, 'Club Brugge KV', 1, 4,
#        'lose', 'away win', 1, 'win', 7.0, 1.53, 3.75, 1], dtype=object), array(['2008-08-30 00:00:00', 207, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 492499, 10001, 'KVC Westerlo', 9993, 'Beerschot AC',
#        1, 0, 'win', 'home win', 0, 'lose', 2.25, 2.8, 3.3, 0],
#       dtype=object), array(['2008-11-23 00:00:00', 21554, 21518, 21518, 'Spain LIGA BBVA',
#        '2008/2009', 530259, 8661, 'RCD Mallorca', 9864, 'Málaga CF', 2, 2,
#        'draw', 'draw', 2, 'draw', 2.1, 3.4, 3.4, 0], dtype=object), array(['2009-04-18 00:00:00', 209, 1, 1, 'Belgium Jupiler League',
#        '2008/2009', 493071, 9996, 'Royal Excel Mouscron', 9985,
#        'Standard de Liège', 0, 3, 'lose', 'away win', 1, 'win', 6.0, 1.57,
#        3.75, 1], dtype=object), array(['2013-01-12 00:00:00', 23144, 21518, 21518, 'Spain LIGA BBVA',
#        '2012/2013', 1260336, 10281, 'Real Valladolid', 8661,
#        'RCD Mallorca', 3, 1, 'win', 'home win', 0, 'lose', 2.0, 3.75, 3.4,
#        0], dtype=object), array(['2010-08-21 00:00:00', 8423, 7809, 7809, 'Germany 1. Bundesliga',
#        '2010/2011', 856876, 9788, 'Borussia Mönchengladbach', 8165,
#        '1. FC Nürnberg', 1, 1, 'draw', 'draw', 2, 'draw', 1.91, 4.0, 3.4,
#        0], dtype=object), array(['2011-03-20 00:00:00', 22494, 21518, 21518, 'Spain LIGA BBVA',
#        '2010/2011', 875884, 10278, 'Hércules Club de Fútbol', 8371,
#        'CA Osasuna', 0, 4, 'lose', 'away win', 1, 'win', 2.15, 3.4, 3.25,
#        1], dtype=object), array(['2010-02-02 00:00:00', 13698, 13274, 13274,
#        'Netherlands Eredivisie', '2009/2010', 662428, 9761, 'NAC Breda',
#        10229, 'AZ', 1, 1, 'draw', 'draw', 2, 'draw', 2.9, 2.4, 3.3, 0],
#       dtype=object), array(['2011-09-18 00:00:00', 22979, 21518, 21518, 'Spain LIGA BBVA',
#        '2011/2012', 1051680, 9906, 'Atlético Madrid', 8696,
#        'Racing Santander', 4, 0, 'win', 'home win', 0, 'lose', 1.44, 7.5,
# ...
#        'home win', 0, 'lose', 2.2, 3.4, 3.2, 0], dtype=object), array(['2015-11-07 00:00:00', 7477, 4769, 4769, 'France Ligue 1',
#        '2015/2016', 1989906, 9847, 'Paris Saint-Germain', 9941,
#        'Toulouse FC', 5, 0, 'win', 'home win', 0, 'lose', 1.18, 17.0, 7.0,
#        1], dtype=object), array(['2015-11-07 00:00:00', 7478, 4769, 4769, 'France Ligue 1',
#        '2015/2016', 1989907, 9837, 'Stade de Reims', 6391, 'GFC Ajaccio',
#        1, 2, 'lose', 'away win', 1, 'win', 1.91, 4.75, 3.2, 0],
#       dtype=object), array(['2015-11-22 00:00:00', 7479, 4769, 4769, 'France Ligue 1',
#        '2015/2016', 1989908, 7794, 'SC Bastia', 6391, 'GFC Ajaccio', 1, 2,
#        'lose', 'away win', 1, 'win', 2.1, 3.8, 3.2, 0], dtype=object), array(['2015-11-22 00:00:00', 7480, 4769, 4769, 'France Ligue 1',
#        '2015/2016', 1989909, 7819, 'SM Caen', 8121, 'Angers SCO', 0, 0,
#        'draw', 'draw', 2, 'draw', 1.8, 5.0, 3.4, 0], dtype=object), array(['2015-11-21 00:00:00', 7481, 4769, 4769, 'France Ligue 1',
#        '2015/2016', 1989910, 9747, 'En Avant de Guingamp', 9941,
#        'Toulouse FC', 2, 0, 'win', 'home win', 0, 'lose', 2.1, 3.6, 3.4,
#        0], dtype=object), array(['2013-02-09 00:00:00', 14624, 13274, 13274,
#        'Netherlands Eredivisie', '2012/2013', 1223121, 10217,
#        'ADO Den Haag', 9761, 'NAC Breda', 2, 1, 'win', 'home win', 0,
#        'lose', 2.0, 3.8, 3.4, 0], dtype=object), array(['2015-11-21 00:00:00', 7483, 4769, 4769, 'France Ligue 1',
#        '2015/2016', 1989912, 9829, 'AS Monaco', 9830, 'FC Nantes', 1, 0,
#        'win', 'home win', 0, 'lose', 1.7, 5.5, 3.6, 0], dtype=object), array(['2015-11-21 00:00:00', 7484, 4769, 4769, 'France Ligue 1',
#        '2015/2016', 1989913, 10249, 'Montpellier Hérault SC', 9837,
#        'Stade de Reims', 3, 1, 'win', 'home win', 0, 'lose', 2.1, 3.75,
#        3.25, 0], dtype=object), array(['2010-12-19 00:00:00', 11102, 10257, 10257, 'Italy Serie A',
#        '2010/2011', 888325, 9875, 'Napoli', 9888, 'Lecce', 1, 0, 'win',
#        'home win', 0, 'lose', 1.36, 9.0, 4.5, 0], dtype=object), array(['2011-08-20 00:00:00', 14391, 13274, 13274,
#        'Netherlands Eredivisie', '2011/2012', 1028495, 8277, 'Vitesse',
#        9908, 'FC Utrecht', 2, 1, 'win', 'home win', 0, 'lose', 1.8, 4.33,
#        3.6, 0], dtype=object), array(['2015-11-22 00:00:00', 7487, 4769, 4769, 'France Ligue 1',
#        '2015/2016', 1989916, 9853, 'AS Saint-Étienne', 8592,
#        'Olympique de Marseille', 0, 2, 'lose', 'away win', 1, 'win', 2.45,
#        3.0, 3.25, 0], dtype=object), array(['2009-02-04 00:00:00', 13398, 13274, 13274,
#        'Netherlands Eredivisie', '2008/2009', 523837, 10229, 'AZ', 9803,
#        'Roda JC Kerkrade', 1, 0, 'win', 'home win', 0, 'lose', 1.25, 9.5,
#        5.0, 0], dtype=object), array(['2011-04-22 00:00:00', 14111, 13274, 13274,
#        'Netherlands Eredivisie', '2010/2011', 836676, 10217,
#        'ADO Den Haag', 8611, 'FC Twente', 1, 2, 'lose', 'away win', 1,
#        'win', 3.4, 2.05, 3.5, 0], dtype=object), array(['2015-11-29 00:00:00', 7490, 4769, 4769, 'France Ligue 1',
#        '2015/2016', 1989919, 9827, 'Girondins de Bordeaux', 7819,
#        'SM Caen', 1, 4, 'lose', 'away win', 1, 'win', 1.95, 4.0, 3.5, 1],
#       dtype=object), array(['2015-11-28 00:00:00', 7491, 4769, 4769, 'France Ligue 1',
#        '2015/2016', 1989920, 6391, 'GFC Ajaccio', 8689, 'FC Lorient', 1,
#        1, 'draw', 'draw', 2, 'draw', 2.8, 2.6, 3.2, 0], dtype=object), array(['2015-11-27 00:00:00', 7492, 4769, 4769, 'France Ligue 1',
#        '2015/2016', 1989921, 9748, 'Olympique Lyonnais', 10249,
#        'Montpellier Hérault SC', 2, 4, 'lose', 'away win', 1, 'win', 1.57,
#        6.5, 3.8, 0], dtype=object), array(['2015-11-29 00:00:00', 7493, 4769, 4769, 'France Ligue 1',
#        '2015/2016', 1989922, 8592, 'Olympique de Marseille', 9829,
#        'AS Monaco', 3, 3, 'draw', 'draw', 2, 'draw', 1.95, 4.0, 3.5, 0],
#       dtype=object), array(['2015-01-10 00:00:00', 21143, 19694, 19694,
#        'Scotland Premier League', '2014/2015', 1726142, 8597,
#        'Kilmarnock', 8066, 'Inverness Caledonian Thistle', 1, 2, 'lose',
#        'away win', 1, 'win', 3.75, 2.0, 3.4, 0], dtype=object), array(['2013-01-30 00:00:00', 20713, 19694, 19694,
#        'Scotland Premier League', '2012/2013', 1230364, 9800,
#        'St. Mirren', 8066, 'Inverness Caledonian Thistle', 2, 1, 'win',
#        'home win', 0, 'lose', 2.88, 2.38, 3.4, 0], dtype=object), array(['2015-11-28 00:00:00', 7496, 4769, 4769, 'France Ligue 1',
#        '2015/2016', 1989925, 9837, 'Stade de Reims', 9851,
#        'Stade Rennais FC', 2, 2, 'draw', 'draw', 2, 'draw', 3.0, 2.6, 3.0,
#        0], dtype=object), array(['2014-01-18 00:00:00', 14896, 13274, 13274,
#        'Netherlands Eredivisie', '2013/2014', 1473187, 10228,
#        'SC Heerenveen', 9803, 'Roda JC Kerkrade', 2, 2, 'draw', 'draw', 2,
#        'draw', 1.62, 4.75, 4.2, 0], dtype=object), array(['2013-01-20 00:00:00', 9120, 7809, 7809, 'Germany 1. Bundesliga',
#        '2012/2013', 1239627, 8165, '1. FC Nürnberg', 9790, 'Hamburger SV',
#        1, 1, 'draw', 'draw', 2, 'draw', 2.3, 3.2, 3.2, 0], dtype=object), array(['2012-03-31 00:00:00', 14374, 13274, 13274,
#        'Netherlands Eredivisie', '2011/2012', 1028924, 8640, 'PSV', 9839,
#        'VVV-Venlo', 2, 0, 'win', 'home win', 0, 'lose', 1.08, 23.0, 10.0,
#        0], dtype=object), array(['2015-12-02 00:00:00', 7500, 4769, 4769, 'France Ligue 1',
#        '2015/2016', 1989929, 7794, 'SC Bastia', 9827,
#        'Girondins de Bordeaux', 1, 0, 'win', 'home win', 0, 'lose', 3.0,
#        2.5, 3.2, 0], dtype=object), array(['2015-12-02 00:00:00', 7501, 4769, 4769, 'France Ligue 1',
#        '2015/2016', 1989930, 9747, 'En Avant de Guingamp', 9837,
#        'Stade de Reims', 1, 2, 'lose', 'away win', 1, 'win', 1.91, 4.5,
#        3.3, 0], dtype=object), array(['2011-12-18 00:00:00', 18394, 17642, 17642,
#        'Portugal Liga ZON Sagres', '2011/2012', 1042926, 10215,
#        'Académica de Coimbra', 9768, 'Sporting CP', 1, 1, 'draw', 'draw',
#        2, 'draw', 5.5, 1.67, 3.5, 0], dtype=object), array(['2015-12-01 00:00:00', 7503, 4769, 4769, 'France Ligue 1',
#        '2015/2016', 1989932, 8689, 'FC Lorient', 9831, 'OGC Nice', 0, 0,
#        'draw', 'draw', 2, 'draw', 2.25, 3.3, 3.3, 0], dtype=object), array(['2013-11-30 00:00:00', 9392, 7809, 7809, 'Germany 1. Bundesliga',
#        '2013/2014', 1479115, 8177, 'Hertha BSC Berlin', 8406,
#        'FC Augsburg', 0, 0, 'draw', 'draw', 2, 'draw', 2.0, 3.6, 3.5, 0],
#       dtype=object), array(['2015-12-02 00:00:00', 7505, 4769, 4769, 'France Ligue 1',
#        '2015/2016', 1989934, 10249, 'Montpellier Hérault SC', 6391,
#        'GFC Ajaccio', 0, 2, 'lose', 'away win', 1, 'win', 1.83, 4.5, 3.5,
#        0], dtype=object), array(['2015-12-01 00:00:00', 7506, 4769, 4769, 'France Ligue 1',
#        '2015/2016', 1989935, 9830, 'FC Nantes', 9748,
#        'Olympique Lyonnais', 0, 0, 'draw', 'draw', 2, 'draw', 3.6, 2.15,
#        3.25, 0], dtype=object), array(['2013-10-07 00:00:00', 19063, 17642, 17642,
#        'Portugal Liga ZON Sagres', '2013/2014', 1498060, 7844,
#        'Vitória Guimarães', 10212, 'CS Marítimo', 1, 0, 'win', 'home win',
#        0, 'lose', 2.2, 3.2, 3.4, 0], dtype=object), array(['2011-12-11 00:00:00', 8790, 7809, 7809, 'Germany 1. Bundesliga',
#        '2011/2012', 1030118, 9789, 'Borussia Dortmund', 8350,
#        '1. FC Kaiserslautern', 1, 1, 'draw', 'draw', 2, 'draw', 1.25,
#        12.0, 5.5, 0], dtype=object), array(['2013-12-01 00:00:00', 12187, 10257, 10257, 'Italy Serie A',
#        '2013/2014', 1536652, 8530, 'Catania', 8564, 'Milan', 1, 3, 'lose',
#        'away win', 1, 'win', 4.75, 1.75, 3.6, 0], dtype=object), array(['2011-09-09 00:00:00', 18557, 17642, 17642,
#        'Portugal Liga ZON Sagres', '2011/2012', 1042857, 9773, 'FC Porto',
#        10238, 'Vitória Setúbal', 3, 0, 'win', 'home win', 0, 'lose', 1.14,
#        21.0, 7.0, 1], dtype=object), array(['2011-05-07 00:00:00', 8662, 7809, 7809, 'Germany 1. Bundesliga',
#        '2010/2011', 857404, 8165, '1. FC Nürnberg', 8226,
#        'TSG 1899 Hoffenheim', 1, 2, 'lose', 'away win', 1, 'win', 1.8,
#        4.33, 3.6, 0], dtype=object), array(['2015-12-05 00:00:00', 7512, 4769, 4769, 'France Ligue 1',
#        '2015/2016', 1989941, 6391, 'GFC Ajaccio', 9830, 'FC Nantes', 1, 1,
#        'draw', 'draw', 2, 'draw', 2.5, 3.1, 3.0, 0], dtype=object), array(['2012-12-26 00:00:00', 20682, 19694, 19694,
#        'Scotland Premier League', '2012/2013', 1229583, 8597,
#        'Kilmarnock', 9860, 'Heart of Midlothian', 1, 0, 'win', 'home win',
#        0, 'lose', 2.8, 2.5, 3.25, 0], dtype=object), array(['2015-12-06 00:00:00', 7514, 4769, 4769, 'France Ligue 1',
#        '2015/2016', 1989943, 8592, 'Olympique de Marseille', 10249,
#        'Montpellier Hérault SC', 2, 2, 'draw', 'draw', 2, 'draw', 1.65,
#        5.5, 3.75, 0], dtype=object), array(['2015-12-04 00:00:00', 7515, 4769, 4769, 'France Ligue 1',
#        '2015/2016', 1989944, 9831, 'OGC Nice', 9847,
#        'Paris Saint-Germain', 0, 3, 'lose', 'away win', 1, 'win', 6.5,
#        1.5, 4.33, 1], dtype=object), array(['2016-04-01 00:00:00', 10133, 7809, 7809, 'Germany 1. Bundesliga',
#        '2015/2016', 2002338, 8178, 'Bayer 04 Leverkusen', 8721,
#        'VfL Wolfsburg', 3, 0, 'win', 'home win', 0, 'lose', 2.0, 4.0, 3.2,
#        1], dtype=object), array(['2008-09-21 00:00:00', 10484, 10257, 10257, 'Italy Serie A',
#        '2008/2009', 539580, 8535, 'Fiorentina', 9857, 'Bologna', 1, 0,
#        'win', 'home win', 0, 'lose', 1.53, 7.5, 3.6, 0], dtype=object), array(['2015-05-17 00:00:00', 19319, 17642, 17642,
#        'Portugal Liga ZON Sagres', '2014/2015', 1750766, 6403,
#        'FC Paços de Ferreira', 10215, 'Académica de Coimbra', 3, 2, 'win',
#        'home win', 0, 'lose', 1.8, 4.33, 3.6, 0], dtype=object), array(['2009-05-10 00:00:00', 13518, 13274, 13274,
#        'Netherlands Eredivisie', '2008/2009', 523948, 8464, 'N.E.C.',
#        8614, 'Sparta Rotterdam', 1, 1, 'draw', 'draw', 2, 'draw', 1.62,
#        5.25, 3.5, 0], dtype=object), array(['2011-05-07 00:00:00', 8658, 7809, 7809, 'Germany 1. Bundesliga',
#        '2010/2011', 857397, 10269, 'VfB Stuttgart', 9904, 'Hannover 96',
#        2, 1, 'win', 'home win', 0, 'lose', 2.1, 3.4, 3.4, 0], dtype=object), array(['2015-09-13 00:00:00', 19644, 17642, 17642,
#        'Portugal Liga ZON Sagres', '2015/2016', 2015840, 8348,
#        'Moreirense FC', 6367, 'Uniao da Madeira', 0, 0, 'draw', 'draw', 2,
#        'draw', 2.25, 3.4, 3.1, 0], dtype=object), array(['2015-12-13 00:00:00', 7522, 4769, 4769, 'France Ligue 1',
#        '2015/2016', 1989951, 9829, 'AS Monaco', 9853, 'AS Saint-Étienne',
#        1, 0, 'win', 'home win', 0, 'lose', 2.05, 4.0, 3.25, 0],
#       dtype=object), array(['2010-09-18 00:00:00', 20349, 19694, 19694,
#        'Scotland Premier League', '2010/2011', 840254, 9927, 'Motherwell',
#        8485, 'Aberdeen', 1, 1, 'draw', 'draw', 2, 'draw', 2.2, 3.25, 3.3,
#        0], dtype=object), array(['2015-12-12 00:00:00', 7524, 4769, 4769, 'France Ligue 1',
#        '2015/2016', 1989953, 9830, 'FC Nantes', 9941, 'Toulouse FC', 1, 1,
#        'draw', 'draw', 2, 'draw', 2.38, 3.3, 3.1, 0], dtype=object), array(['2015-12-13 00:00:00', 7525, 4769, 4769, 'France Ligue 1',
#        '2015/2016', 1989954, 9847, 'Paris Saint-Germain', 9748,
#        'Olympique Lyonnais', 5, 1, 'win', 'home win', 0, 'lose', 1.25,
#        13.0, 5.5, 1], dtype=object), array(['2014-12-14 00:00:00', 23865, 21518, 21518, 'Spain LIGA BBVA',
#        '2014/2015', 1778181, 8302, 'Sevilla FC', 8372, 'SD Eibar', 0, 0,
#        'draw', 'draw', 2, 'draw', 1.4, 9.0, 4.5, 0], dtype=object), array(['2015-12-11 00:00:00', 7527, 4769, 4769, 'France Ligue 1',
#        '2015/2016', 1989956, 9851, 'Stade Rennais FC', 7819, 'SM Caen', 1,
#        1, 'draw', 'draw', 2, 'draw', 2.38, 3.2, 3.25, 0], dtype=object), array(['2009-10-31 00:00:00', 13611, 13274, 13274,
#        'Netherlands Eredivisie', '2009/2010', 662350, 8674,
#        'FC Groningen', 10229, 'AZ', 0, 1, 'lose', 'away win', 1, 'win',
#        2.88, 2.4, 3.3, 0], dtype=object), array(['2015-12-19 00:00:00', 7529, 4769, 4769, 'France Ligue 1',
#        '2015/2016', 1989958, 7794, 'SC Bastia', 9837, 'Stade de Reims', 2,
#        0, 'win', 'home win', 0, 'lose', 2.45, 3.1, 3.1, 0], dtype=object), array(['2015-09-19 00:00:00', 24506, 21518, 21518, 'Spain LIGA BBVA',
#        '2015/2016', 2030120, 10267, 'Valencia CF', 8603,
#        'Real Betis Balompié', 0, 0, 'draw', 'draw', 2, 'draw', 1.5, 6.5,
#        4.33, 0], dtype=object), array(['2015-12-19 00:00:00', 7531, 4769, 4769, 'France Ligue 1',
#        '2015/2016', 1989960, 7819, 'SM Caen', 9847, 'Paris Saint-Germain',
#        0, 3, 'lose', 'away win', 1, 'win', 7.0, 1.5, 4.2, 1], dtype=object), array(['2013-01-19 00:00:00', 14590, 13274, 13274,
#        'Netherlands Eredivisie', '2012/2013', 1223049, 8611, 'FC Twente',
#        10219, 'RKC Waalwijk', 0, 0, 'draw', 'draw', 2, 'draw', 1.33, 9.0,
#        5.0, 0], dtype=object), array(['2015-12-19 00:00:00', 7533, 4769, 4769, 'France Ligue 1',
#        '2015/2016', 1989962, 9747, 'En Avant de Guingamp', 9851,
#        'Stade Rennais FC', 0, 2, 'lose', 'away win', 1, 'win', 2.5, 3.2,
#        3.0, 0], dtype=object), array(['2014-11-23 00:00:00', 9677, 7809, 7809, 'Germany 1. Bundesliga',
#        '2014/2015', 1732825, 10269, 'VfB Stuttgart', 8406, 'FC Augsburg',
#        0, 1, 'lose', 'away win', 1, 'win', 2.38, 2.8, 3.5, 0],
#       dtype=object), array(['2012-05-02 00:00:00', 14426, 13274, 13274,
#        'Netherlands Eredivisie', '2011/2012', 1029004, 8674,
#        'FC Groningen', 9761, 'NAC Breda', 1, 1, 'draw', 'draw', 2, 'draw',
#        2.0, 3.75, 3.4, 0], dtype=object), array(['2011-01-09 00:00:00', 11118, 10257, 10257, 'Italy Serie A',
#        '2010/2011', 888341, 10167, 'Parma', 8529, 'Cagliari', 1, 2,
#        'lose', 'away win', 1, 'win', 2.1, 3.75, 3.1, 0], dtype=object), array(['2015-12-19 00:00:00', 7537, 4769, 4769, 'France Ligue 1',
#        '2015/2016', 1989966, 9941, 'Toulouse FC', 8639, 'LOSC Lille', 1,
#        1, 'draw', 'draw', 2, 'draw', 2.55, 3.0, 3.1, 0], dtype=object), array(['2014-10-18 00:00:00', 9935, 7809, 7809, 'Germany 1. Bundesliga',
#        '2014/2015', 1732780, 9905, '1. FSV Mainz 05', 8406, 'FC Augsburg',
#        2, 1, 'win', 'home win', 0, 'lose', 2.3, 3.0, 3.4, 0], dtype=object), array(['2013-12-08 00:00:00', 12204, 10257, 10257, 'Italy Serie A',
#        '2013/2014', 1536669, 9804, 'Torino', 8543, 'Lazio', 1, 0, 'win',
#        'home win', 0, 'lose', 2.38, 3.0, 3.2, 0], dtype=object), array(['2015-08-15 00:00:00', 7540, 4769, 4769, 'France Ligue 1',
#        '2015/2016', 1989789, 7819, 'SM Caen', 9941, 'Toulouse FC', 1, 0,
#        'win', 'home win', 0, 'lose', 2.2, 3.25, 3.4, 0], dtype=object), array(['2015-08-15 00:00:00', 7541, 4769, 4769, 'France Ligue 1',
#        '2015/2016', 1989790, 9747, 'En Avant de Guingamp', 9748,
#        'Olympique Lyonnais', 0, 1, 'lose', 'away win', 1, 'win', 3.6,
#        2.15, 3.25, 0], dtype=object), array(['2015-08-16 00:00:00', 7542, 4769, 4769, 'France Ligue 1',
#        '2015/2016', 1989791, 8689, 'FC Lorient', 7794, 'SC Bastia', 1, 1,
#        'draw', 'draw', 2, 'draw', 1.85, 4.75, 3.4, 0], dtype=object), array(['2015-08-14 00:00:00', 7543, 4769, 4769, 'France Ligue 1',
#        '2015/2016', 1989792, 9829, 'AS Monaco', 8639, 'LOSC Lille', 0, 0,
#        'draw', 'draw', 2, 'draw', 1.62, 6.5, 3.6, 0], dtype=object), array(['2012-08-25 00:00:00', 9040, 7809, 7809, 'Germany 1. Bundesliga',
#        '2012/2013', 1239465, 8357, 'SpVgg Greuther Fürth', 9823,
#        'FC Bayern Munich', 0, 3, 'lose', 'away win', 1, 'win', 8.5, 1.36,
#        4.75, 1], dtype=object), array(['2014-11-08 00:00:00', 9667, 7809, 7809, 'Germany 1. Bundesliga',
#        '2014/2015', 1732815, 8226, 'TSG 1899 Hoffenheim', 8722,
#        '1. FC Köln', 3, 4, 'lose', 'away win', 1, 'win', 1.8, 4.0, 3.8, 0],
#       dtype=object), array(['2015-08-15 00:00:00', 7546, 4769, 4769, 'France Ligue 1',
#        '2015/2016', 1989795, 9851, 'Stade Rennais FC', 10249,
#        'Montpellier Hérault SC', 1, 0, 'win', 'home win', 0, 'lose', 2.25,
#        3.5, 3.1, 0], dtype=object)]

# %%
reservoir_match_final = pd.DataFrame(data=reservoir, columns=match_final.columns)

# %%
reservoir_match_final
# Out:
#                      date     id  league_id  country_id  \
# 0     2008-08-17 00:00:00      1          1           1
# 1     2013-09-21 00:00:00   9613       7809        7809
# 2     2008-08-16 00:00:00      3          1           1
# 3     2016-03-04 00:00:00  19549      17642       17642
# 4     2008-08-16 00:00:00      5          1           1
# ...                   ...    ...        ...         ...
# 7541  2015-08-16 00:00:00   7542       4769        4769
# 7542  2015-08-14 00:00:00   7543       4769        4769
# 7543  2012-08-25 00:00:00   9040       7809        7809
# 7544  2014-11-08 00:00:00   9667       7809        7809
# 7545  2015-08-15 00:00:00   7546       4769        4769
#
#                 league_country     season  match_api_id  home_team_api_id  \
# 0       Belgium Jupiler League  2008/2009        492473              9987
# 1        Germany 1. Bundesliga  2013/2014       1479039              8721
# 2       Belgium Jupiler League  2008/2009        492475              9984
# 3     Portugal Liga ZON Sagres  2015/2016       2016033              6403
# 4       Belgium Jupiler League  2008/2009        492477              7947
# ...                        ...        ...           ...               ...
# 7541            France Ligue 1  2015/2016       1989791              8689
# 7542            France Ligue 1  2015/2016       1989792              9829
# 7543     Germany 1. Bundesliga  2012/2013       1239465              8357
# 7544     Germany 1. Bundesliga  2014/2015       1732815              8226
# 7545            France Ligue 1  2015/2016       1989795              9851
#
#                  home_team  away_team_api_id  ... home_team_goal  \
# 0                 KRC Genk              9993  ...              1
# 1            VfL Wolfsburg              8226  ...              2
# 2        KSV Cercle Brugge              8635  ...              0
# 3     FC Paços de Ferreira             10212  ...              2
# 4            FCV Dender EH              9985  ...              1
# ...                    ...               ...  ...            ...
# 7541            FC Lorient              7794  ...              1
# 7542             AS Monaco              8639  ...              0
# 7543  SpVgg Greuther Fürth              9823  ...              0
# 7544   TSG 1899 Hoffenheim              8722  ...              3
# 7545      Stade Rennais FC             10249  ...              1
#
#       away_team_goal  home_result general_result general_encoded_result  \
# 0                  1         draw           draw                      2
# 1                  1          win       home win                      0
# 2                  3         lose       away win                      1
# 3                  2         draw           draw                      2
# 4                  3         lose       away win                      1
# ...              ...          ...            ...                    ...
# 7541               1         draw           draw                      2
# 7542               0         draw           draw                      2
# 7543               3         lose       away win                      1
# 7544               4         lose       away win                      1
# 7545               0          win       home win                      0
#
#       away_result B365H  B365A  B365D  3+_goals_diff
# 0            draw  1.73   5.00   3.40              0
# 1            lose  1.73   4.20   4.00              0
# 2             win  2.38   2.75   3.30              1
# 3            draw  2.45   2.90   3.25              0
# 4             win  5.00   1.65   3.50              0
# ...           ...   ...    ...    ...            ...
# 7541         draw  1.85   4.75   3.40              0
# 7542         draw  1.62   6.50   3.60              0
# 7543          win  8.50   1.36   4.75              1
# 7544          win  1.80   4.00   3.80              0
# 7545         lose  2.25   3.50   3.10              0
#
# [7546 rows x 21 columns]
